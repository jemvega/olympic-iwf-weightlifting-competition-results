# %%
"iwf-competition-analysis-visualizations"
"""Questions:
What is the average body weight for men and women?
What is the average weight of successful Max Snatch, 
    Max C/J, and Total for IWF, Oly, and all for men and women?
What is ratio of missed lifts to completed lifts 
    for Oly, IWF, and all for men and women?
What are the top 10 most popular country codes?
What is the ratio of female to male competitors for Oly, IWF, and all?
Is the number of female competitors increasing? 
Is there a correlation between body weight and 
    max snatch, max c/j, and total for men and women?
    
Comparison of max snatch, max c/j, and totals for 
    weight classes by 5kg increments for men and women. 
    




Need to clean up country codes? Perhaps using regular expressions?"""

# %%
# # A function to concate all of the above .csv files into one file
# file_name = "Olympic-Weightlifting-total-results-1980-2016"
# wf.datatable_cleanup.concat_csv(file_name)

# import os
# from glob import glob
# import pandas as pd
# import webscraping_functions as wf

# %%
from datetime import datetime
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

import webscraping_functions as wf

# #plt.show()

# %%
# Setting custom color palette from hex color codes 
"""
Hexcodes and Color Names
"#B38867", # Coffee
"#283655", # Blueberry
"#69983D", # Green Apple
"#D50000", # Guardsman Red
"#A57298", # Boquet
"#FFAA00", # Web Orange/Goldenrod
"#F18D93", # Pink Tulip
"#F0810F", # Tangerine
"#66A5AD", # Ocean
"""

color_names = "coffee, blueberry, green, red, boquet, goldenrod, pink tulip, tangerine, ocean".split(", ")
hexcodes = "#B38867 #283655 #69983D #D50000 #A57298 #FFAA00 #F18D93 #F0810F #66A5AD".split()
colors_codes = list(zip(color_names, hexcodes))
exercise_names = "Deadlift BackSquat OverheadSquat FrontSquat BenchPress ShoulderPress SnatchPress Snatch Clean&Jerk".split()
color_map= dict(zip(exercise_names, colors_codes))

# %%
color_df = pd.DataFrame.from_dict(color_map, orient="index", columns=["Color Name", "Hexcode"])
color_df
# Out:
#                Color Name  Hexcode
# Deadlift           coffee  #B38867
# BackSquat       blueberry  #283655
# OverheadSquat       green  #69983D
# FrontSquat            red  #D50000
# BenchPress         boquet  #A57298
# ShoulderPress   goldenrod  #FFAA00
# SnatchPress    pink tulip  #F18D93
# Snatch          tangerine  #F0810F
# Clean&Jerk          ocean  #66A5AD

# %%
colors = color_df["Hexcode"].tolist()

# %%
palette = sns.set_palette(sns.color_palette(colors))
sns.set_context("paper")

# %%
df = pd.read_csv("iwf-oly-weightlifting-combined-total-results-1980-2016.csv", encoding='utf-8')
df.head()
# Out:
#    Unnamed: 0  Year Event Gender  Comp Rank       Athlete Name Nationality  \
# 0           0  1996   iwf      W        1.0             Wan Ni         CHN
# 1           1  1996   iwf      W        2.0  Karoliina Lundahl         FIN
# 2           2  1996   iwf      W        3.0    Chen Hsiao-lien         TPE
# 3           3  1996   iwf      W        4.0       Sylvie Iskin         FRA
# 4           4  1996   iwf      W        5.0    Erika TakÃƒÂ¡cs         HUN
#
#   Group  Body Weight (kg)  Snatch 1 (kg)  Snatch 2 (kg)  Snatch 3 (kg)  \
# 0     A             84.40          102.5         -107.5         -110.0
# 1     A             83.10          100.0          105.0          107.5
# 2     A            100.40          -95.0          -97.5           97.5
# 3     A             96.85         -100.0          100.0          102.5
# 4     A             96.00           97.5         -100.0         -100.0
#
#    Max Snatch  Snatch Rank  C/J 1 (kg)  C/J 2 (kg)  C/J 3 (kg)  Max C/J  \
# 0       102.5            2       130.0       135.0       137.5    137.5
# 1       107.5            1       125.0      -127.5      -127.5    125.0
# 2        97.5            4       130.0      -137.5      -137.5    130.0
# 3       102.5            2       117.5      -122.5       122.5    122.5
# 4        97.5            4       120.0      -125.0      -125.0    120.0
#
#    C/J Rank  Total
# 0         1  240.0
# 1         3  232.5
# 2         2  227.5
# 3         4  225.0
# 4         5  217.5

# %%
df.drop(columns =["Unnamed: 0"], inplace = True)
df["Body Weight (kg)"] = wf.ResultsCleanup.string_to_float(df["Body Weight (kg)"].values.tolist())
df["Snatch 1 (kg)"] = wf.ResultsCleanup.string_to_float(df["Snatch 1 (kg)"].values.tolist())
df["Snatch 2 (kg)"] = wf.ResultsCleanup.string_to_float(df["Snatch 2 (kg)"].values.tolist())
df["Snatch 3 (kg)"] = wf.ResultsCleanup.string_to_float(df["Snatch 3 (kg)"].values.tolist())
df["C/J 1 (kg)"] = wf.ResultsCleanup.string_to_float(df["C/J 1 (kg)"].values.tolist())
df["C/J 2 (kg)"] = wf.ResultsCleanup.string_to_float(df["C/J 2 (kg)"].values.tolist())
df["C/J 3 (kg)"] = wf.ResultsCleanup.string_to_float(df["C/J 3 (kg)"].values.tolist())
df["Max Snatch"] = wf.ResultsCleanup.string_to_float(df["Max Snatch"].values.tolist())
df["Max C/J"] = wf.ResultsCleanup.string_to_float(df["Max C/J"].values.tolist())
df["Total"] = wf.ResultsCleanup.string_to_float(df["Total"].values.tolist())
wf.CheckFunctions.change_nation_code(df)
df.fillna(0, inplace=True)
df.head()
# Out:
#    Year Event Gender  Comp Rank       Athlete Name Nationality Group  \
# 0  1996   iwf      W        1.0             Wan Ni         CHN     A
# 1  1996   iwf      W        2.0  Karoliina Lundahl         FIN     A
# 2  1996   iwf      W        3.0    Chen Hsiao-lien         TPE     A
# 3  1996   iwf      W        4.0       Sylvie Iskin         FRA     A
# 4  1996   iwf      W        5.0    Erika TakÃƒÂ¡cs         HUN     A
#
#    Body Weight (kg)  Snatch 1 (kg)  Snatch 2 (kg)  Snatch 3 (kg)  Max Snatch  \
# 0             84.40          102.5         -107.5         -110.0       102.5
# 1             83.10          100.0          105.0          107.5       107.5
# 2            100.40          -95.0          -97.5           97.5        97.5
# 3             96.85         -100.0          100.0          102.5       102.5
# 4             96.00           97.5         -100.0         -100.0        97.5
#
#    Snatch Rank  C/J 1 (kg)  C/J 2 (kg)  C/J 3 (kg)  Max C/J  C/J Rank  Total
# 0            2       130.0       135.0       137.5    137.5         1  240.0
# 1            1       125.0      -127.5      -127.5    125.0         3  232.5
# 2            4       130.0      -137.5      -137.5    130.0         2  227.5
# 3            2       117.5      -122.5       122.5    122.5         4  225.0
# 4            4       120.0      -125.0      -125.0    120.0         5  217.5

# %%
df.head()[::-1]

# %%
df[::-1]
# Out:
#        Year Event Gender  Comp Rank                     Athlete Name  \
# 10198  2016   oly      W        0.0               Jaqueline Ferreira
# 10197  2016   oly      W       14.0                     Samira Ouass
# 10196  2016   oly      W       13.0                   Assiya Ã„Â°pek
# 10195  2016   oly      W       12.0             Natalia PriÃˆâ„¢cepa
# 10194  2016   oly      W       11.0                     Mary Opeloge
# 10193  2016   oly      W       10.0                   Sona Poghosyan
# 10192  2016   oly      W        9.0                  Alejandra Garza
# 10191  2016   oly      W        8.0         GaÃƒÂ«lle Nayo-Ketchanke
# 10190  2016   oly      W        7.0      MarÃƒÂ­a Fernanda ValdÃƒÂ©s
# 10189  2016   oly      W        6.0                     Jenny Arthur
# 10188  2016   oly      W        5.0                      Iryna Dekha
# 10187  2016   oly      W        4.0                 Ubaldina Valoyes
# 10186  2016   oly      W        3.0                Lidia ValentÃƒÂ­n
# 10185  2016   oly      W        2.0                    Darya Naumava
# 10184  2016   oly      W        1.0                     Rim Jong-sim
# 10183  2016   oly      W        0.0            Anastasiya Mikhalenka
# 10182  2016   oly      W        0.0            Florina Sorina Hulpan
# 10181  2016   oly      W        0.0              Patrycja Piechowiak
# 10180  2016   oly      W       14.0              Arcangeline Fouodji
# 10179  2016   oly      W       13.0                Gulnabat Kadyrova
# 10178  2016   oly      W       12.0                  Duygu AynacÃ„Â±
# 10177  2016   oly      W       11.0                  Apolonia Vaivai
# 10176  2016   oly      W       10.0                    Rebekah Tiler
# 10175  2016   oly      W        9.0   Marie-ÃƒË†ve Beauchemin-Nadeau
# 10174  2016   oly      W        8.0  MÃƒÂ¶nkhjantsangiin Ankhtsetseg
# 10173  2016   oly      W        7.0                    Neisi Dajomes
# 10172  2016   oly      W        6.0                   Darya Pachabut
# 10171  2016   oly      W        5.0                   Nazik Avdalyan
# 10170  2016   oly      W        4.0                   Leydi SolÃƒÂ­s
# 10169  2016   oly      W        3.0                       Sara Ahmed
# ...     ...   ...    ...        ...                              ...
# 29     1996   iwf      W        6.0                    Alfia Galieva
# 28     1996   iwf      W        5.0                  Maryse Turcotte
# 27     1996   iwf      W        4.0                     Neli Yankova
# 26     1996   iwf      W        3.0                Karnam Malleswari
# 25     1996   iwf      W        2.0                    Kuo Ping-chun
# 24     1996   iwf      W        1.0                    Zhang Xixiang
# 23     1996   iwf      W        0.0                     Amanda Inman
# 22     1996   iwf      W        9.0                 ErzsÃƒÂ©bet Nagy
# 21     1996   iwf      W        8.0                  Csilla FÃƒÂ¶ldi
# 20     1996   iwf      W        7.0                     Siyka Stoeva
# 19     1996   iwf      W        6.0                  Noriko Hasegawa
# 18     1996   iwf      W        5.0                    Anna Stroubou
# 17     1996   iwf      W        4.0                 Izabela Rifatova
# 16     1996   iwf      W        3.0                      Chu Nan-mei
# 15     1996   iwf      W        2.0                  Choi Myung-shik
# 14     1996   iwf      W        1.0                       Liu Xiuhua
# 13     1996   iwf      W        7.0                    Loreen Briner
# 12     1996   iwf      W        6.0                 Lubov Averianova
# 11     1996   iwf      W        5.0                   Donka Mincheva
# 10     1996   iwf      W        4.0                   Kaori Niyanagi
# 9      1996   iwf      W        3.0                   Tsai Huey-woan
# 8      1996   iwf      W        2.0                   Kunjarani Devi
# 7      1996   iwf      W        1.0                        Guan Hong
# 6      1996   iwf      W        7.0                    Decia Stenzel
# 5      1996   iwf      W        6.0                 Stamatia Bontozi
# 4      1996   iwf      W        5.0                  Erika TakÃƒÂ¡cs
# 3      1996   iwf      W        4.0                     Sylvie Iskin
# 2      1996   iwf      W        3.0                  Chen Hsiao-lien
# 1      1996   iwf      W        2.0                Karoliina Lundahl
# 0      1996   iwf      W        1.0                           Wan Ni
#
#          Nationality Group Body Weight (kg) Snatch 1 (kg) Snatch 2 (kg)  \
# 10198         Brazil     A            74.89          -103          -103
# 10197        Morocco     B            73.68            70            75
# 10196         Turkey     B            69.77            80            83
# 10195        Moldova     B            73.72            93            97
# 10194          Samoa     B            74.56            97           100
# 10193        Armenia     B            72.52            92            97
# 10192         Mexico     B            74.59           -98            98
# 10191         France     A            73.61           102          -107
# 10190          Chile     B            74.66          -107          -107
# 10189  United States     A            74.65          -103           103
# 10188        Ukraine     A            74.89           111           114
# 10187       Colombia     A            74.28           106           109
# 10186          Spain     A               74           112          -116
# 10185        Belarus     A            74.63           107           112
# 10184    North Korea     A            74.47           117          -121
# 10183        Belarus     A            67.23          -103          -103
# 10182        Romania     A            67.52          -100          -100
# 10181         Poland     B            68.32            98           101
# 10180       Cameroon     B            68.08            77            82
# 10179   Turkmenistan     B            68.73            85            90
# 10178         Turkey     B            68.83            85            88
# 10177           Fiji     B            68.88           -88            88
# 10176  Great Britain     B            68.59            98          -101
# 10175         Canada     A            68.81           -98            98
# 10174       Mongolia     A            68.97          -106           106
# 10173        Ecuador     B            68.83           100           104
# 10172        Belarus     A            66.88          -105           105
# 10171        Armenia     A            68.55           103          -107
# 10170       Colombia     A            68.61           106          -110
# 10169          Egypt     A               68           107           110
# ...              ...   ...              ...           ...           ...
# 29               RUS     A            53.95            65           -70
# 28               CAN     A            53.85          67.5            70
# 27               BUL     A            53.05            75           -80
# 26               IND     A             53.9            80           -85
# 25               TPE     A             53.6            80            85
# 24               CHN     A               54          82.5          87.5
# 23               AUS     A            49.05          57.5           -60
# 22               HUN     A            49.05          57.5           -60
# 21               HUN     A            49.35            60            65
# 20               BUL     A             49.6          67.5           -70
# 19               JPN     A               50          67.5           -70
# 18               GRE     A            49.45            70          72.5
# 17               BUL     A            49.75          72.5          77.5
# 16               TPE     A            49.15            75          77.5
# 15               KOR     A            49.95            75          77.5
# 14               CHN     A             49.9         -77.5           -80
# 13               USA     A            45.85            60            65
# 12               RUS     A             45.8          62.5             0
# 11               BUL     A             45.8            65         -67.5
# 10               JPN     A             45.8          62.5          67.5
# 9                TPE     A             45.6          67.5            70
# 8                IND     A            45.45         -67.5         -67.5
# 7                CHN     A            44.75          72.5         -77.5
# 6                USA     A             85.6           -90            90
# 5                GRE     A            108.9          82.5           -85
# 4                HUN     A               96          97.5          -100
# 3                FRA     A            96.85          -100           100
# 2                TPE     A            100.4           -95         -97.5
# 1                FIN     A             83.1           100           105
# 0                CHN     A             84.4         102.5        -107.5
#
#       Snatch 3 (kg) Max Snatch  Snatch Rank C/J 1 (kg) C/J 2 (kg) C/J 3 (kg)  \
# 10198          -103       -103           15          0          0          0
# 10197           -80         75           14         90        -96         97
# 10196           -85         83           13         95        100        103
# 10195          -100         97           11        110        116       -123
# 10194          -102        100            9        115        117        118
# 10193          -100         97           11        115        122        126
# 10192          -101         98           10       -125        125        126
# 10191          -107        102            8        132        135       -140
# 10190           107        107            6        135       -142       -142
# 10189           107        107            6        130        135       -141
# 10188          -116        114            4        133       -138       -141
# 10187           111        111            5        131        136       -138
# 10186           116        116            2        135        138        141
# 10185           116        116            2        136        139        142
# 10184           121        121            1        145        153       -162
# 10183          -103       -103           17          0          0          0
# 10182           100        100           11          0          0          0
# 10181          -103        101            9          0          0          0
# 10180           -86         82           16        100        105       -110
# 10179           -94         90           13       -100       -105        105
# 10178            90         90           13        105       -110        110
# 10177           -92         88           15        108        113       -117
# 10176           101        101            9        122       -126        126
# 10175          -103         98           12        130       -135       -136
# 10174          -108        106            7        131       -135       -135
# 10173           107        107            5        130       -135       -135
# 10172          -108        105            8        126        132       -137
# 10171           107        107            5        130        133        135
# 10170           110        110            4        140        143       -146
# 10169           112        112            3        135        140        143
# ...             ...        ...          ...        ...        ...        ...
# 29              -70         65            9         90         95      -97.5
# 28            -72.5         70            6         90         95      -97.5
# 27              -80         75            5         95        100     -102.5
# 26               85         85            2     -102.5     -102.5      102.5
# 25            -87.5         85            2      102.5     -107.5     -107.5
# 24              -90       87.5            1        105       -110        110
# 23              -60       57.5            9      -72.5      -72.5      -72.5
# 22              -60       57.5            9         75         80      -82.5
# 21            -67.5         65            8         80        -85        -85
# 20              -70       67.5            7        -85         85        -90
# 19               70         70            6        -85         85         90
# 18              -75       72.5            5         85      -87.5       87.5
# 17              -80       77.5            3      -92.5       92.5      -97.5
# 16              -80       77.5            3         95      -97.5      -97.5
# 15               80         80            1         95       -100       -100
# 14               80         80            1        100      102.5        105
# 13              -70         65            6       72.5      -77.5        -80
# 12                0       62.5            7       82.5          0          0
# 11             67.5       67.5            3        -80         80       82.5
# 10              -70       67.5            3         85        -90        -90
# 9             -72.5         70            2         85       87.5        -90
# 8              67.5       67.5            3       87.5         90      -97.5
# 7              77.5       77.5            1         95     -105.5     -105.5
# 6               -95         90            6        105       -110       -110
# 5              87.5       87.5            7        110        115     -117.5
# 4              -100       97.5            4        120       -125       -125
# 3             102.5      102.5            2      117.5     -122.5      122.5
# 2              97.5       97.5            4        130     -137.5     -137.5
# 1             107.5      107.5            1        125     -127.5     -127.5
# 0              -110      102.5            2        130        135      137.5
#
#       Max C/J  C/J Rank  Total
# 10198       0        15      0
# 10197      97        14    172
# 10196     103        13    186
# 10195     116        12    213
# 10194     118        11    218
# 10193     126         9    223
# 10192     126         9    224
# 10191     135         5    237
# 10190     135         5    242
# 10189     135         5    242
# 10188     133         8    247
# 10187     136         4    247
# 10186     141         3    257
# 10185     142         2    258
# 10184     153         1    274
# 10183       0        15      0
# 10182       0        15      0
# 10181       0        15      0
# 10180     105        13    187
# 10179     105        13    195
# 10178     110        12    200
# 10177     113        11    201
# 10176     126        10    227
# 10175     130         8    228
# 10174     131         7    237
# 10173     130         8    237
# 10172     132         6    237
# 10171     135         5    242
# 10170     143         3    253
# 10169     143         3    255
# ...       ...       ...    ...
# 29         95         5    160
# 28         95         5    165
# 27        100         4    175
# 26      102.5         2  187.5
# 25      102.5         2  187.5
# 24        110         1  197.5
# 23      -72.5        10      0
# 22         80         8  137.5
# 21         80         8    145
# 20         85         7  152.5
# 19         90         5    160
# 18       87.5         6    160
# 17       92.5         4    170
# 16         95         2  172.5
# 15         95         2    175
# 14        105         1    185
# 13       72.5         7  137.5
# 12       82.5         5    145
# 11       82.5         5    150
# 10         85         4  152.5
# 9        87.5         3  157.5
# 8          90         2  157.5
# 7          95         1  172.5
# 6         105         7    195
# 5         115         6  202.5
# 4         120         5  217.5
# 3       122.5         4    225
# 2         130         2  227.5
# 1         125         3  232.5
# 0       137.5         1    240
#
# [10199 rows x 19 columns]

# %%
# country_codes = pd.read_csv("country-codes-alpha-2-3.csv")
country_codes = pd.read_csv("country-codes-alpha-3-only.csv")
country_codes.drop("Unnamed: 0", axis=1, inplace=True)
country_codes.head()
# Out:
#   Alpha-3 code        Country
# 0          ABW          Aruba
# 1          AFG    Afghanistan
# 2          AGO         Angola
# 3          AIA       Anguilla
# 4          ALA  Åland Islands

# %%
if df["Nationality"][10198] in country_codes["Country"].values.tolist():
    print("True")
else:
    print('F')
# Out:
# True

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def country_codes(website_url):
    code_text = []
    url = requests.get(website_url)
    page = BeautifulSoup(url.text, 'lxml')
    wiki_table = page.find("div", class_= "plainlist")
    code_data = wiki_table.find_all("li")
    for text in code_data:
        code_text.append(text.get_text())
    return code_text

# %%
def country_codes(website_url):
    code_text = []
    url = requests.get(website_url)
    page = BeautifulSoup(url.text, 'lxml')
    wiki_table = page.find("div", class_= "plainlist")
    code_data = wiki_table.find_all(["span", "a"])
    for text in code_data:
        code_text.append(text.get_text())
    return code_text

website_url = "https://en.wikipedia.org/wiki/ISO_3166-1_alpha-3"
code_letters = country_codes(website_url)[0::2]
country_names = country_codes(website_url)[1::2]

# %%
website_url = "https://en.wikipedia.org/wiki/ISO_3166-1_alpha-3"
leslie = country_codes(website_url)

# %%
j = leslie[0].split("}")

# %%
j.pop(0)
# Out:
# '.mw-parser-output .monospaced{font-family:monospace,monospace'

# %%
j
# Out:
# ['ABW\xa0\xa0Aruba']

# %%
for elem in leslie:
    elem.split("}")
    elem.split("\xa0")

    print(elem)
# Out:
# .mw-parser-output .monospaced{font-family:monospace,monospace}ABW  Aruba
# AFG  Afghanistan
# AGO  Angola
# AIA  Anguilla
# ALA  Åland Islands
# ALB  Albania
# AND  Andorra
# ARE  United Arab Emirates
# ARG  Argentina
# ARM  Armenia
# ASM  American Samoa
# ATA  Antarctica
# ATF  French Southern Territories
# ATG  Antigua and Barbuda
# AUS  Australia
# AUT  Austria
# AZE  Azerbaijan
# BDI  Burundi
# BEL  Belgium
# BEN  Benin
# BES  Bonaire, Sint Eustatius and Saba
# BFA  Burkina Faso
# BGD  Bangladesh
# BGR  Bulgaria
# BHR  Bahrain
# BHS  Bahamas
# BIH  Bosnia and Herzegovina
# BLM  Saint Barthélemy
# BLR  Belarus
# BLZ  Belize
# BMU  Bermuda
# BOL  Bolivia (Plurinational State of)
# BRA  Brazil
# BRB  Barbados
# BRN  Brunei Darussalam
# BTN  Bhutan
# BVT  Bouvet Island
# BWA  Botswana
# CAF  Central African Republic
# CAN  Canada
# CCK  Cocos (Keeling) Islands
# CHE  Switzerland
# CHL  Chile
# CHN  China
# CIV  Côte d'Ivoire
# CMR  Cameroon
# COD  Congo, Democratic Republic of the
# COG  Congo
# COK  Cook Islands
# COL  Colombia
# COM  Comoros
# CPV  Cabo Verde
# CRI  Costa Rica
# CUB  Cuba
# CUW  Curaçao
# CXR  Christmas Island
# CYM  Cayman Islands
# CYP  Cyprus
# CZE  Czechia
# DEU  Germany
# DJI  Djibouti
# DMA  Dominica
# DNK  Denmark
# DOM  Dominican Republic
# DZA  Algeria
# ECU  Ecuador
# EGY  Egypt
# ERI  Eritrea
# ESH  Western Sahara
# ESP  Spain
# EST  Estonia
# ETH  Ethiopia
# FIN  Finland
# FJI  Fiji
# FLK  Falkland Islands (Malvinas)
# FRA  France
# FRO  Faroe Islands
# FSM  Micronesia (Federated States of)
# GAB  Gabon
# GBR  United Kingdom of Great Britain and Northern Ireland
# GEO  Georgia
# GGY  Guernsey
# GHA  Ghana
# GIB  Gibraltar
# GIN  Guinea
# GLP  Guadeloupe
# GMB  Gambia
# GNB  Guinea-Bissau
# GNQ  Equatorial Guinea
# GRC  Greece
# GRD  Grenada
# GRL  Greenland
# GTM  Guatemala
# GUF  French Guiana
# GUM  Guam
# GUY  Guyana
# HKG  Hong Kong
# HMD  Heard Island and McDonald Islands
# HND  Honduras
# HRV  Croatia
# HTI  Haiti
# HUN  Hungary
# IDN  Indonesia
# IMN  Isle of Man
# IND  India
# IOT  British Indian Ocean Territory
# IRL  Ireland
# IRN  Iran (Islamic Republic of)
# IRQ  Iraq
# ISL  Iceland
# ISR  Israel
# ITA  Italy
# JAM  Jamaica
# JEY  Jersey
# JOR  Jordan
# JPN  Japan
# KAZ  Kazakhstan
# KEN  Kenya
# KGZ  Kyrgyzstan
# KHM  Cambodia
# KIR  Kiribati
# KNA  Saint Kitts and Nevis
# KOR  Korea, Republic of
# KWT  Kuwait
# LAO  Lao People's Democratic Republic
# LBN  Lebanon
# LBR  Liberia
# LBY  Libya
# LCA  Saint Lucia
# LIE  Liechtenstein
# LKA  Sri Lanka
# LSO  Lesotho
# LTU  Lithuania
# LUX  Luxembourg
# LVA  Latvia
# MAC  Macao
# MAF  Saint Martin (French part)
# MAR  Morocco
# MCO  Monaco
# MDA  Moldova, Republic of
# MDG  Madagascar
# MDV  Maldives
# MEX  Mexico
# MHL  Marshall Islands
# MKD  North Macedonia
# MLI  Mali
# MLT  Malta
# MMR  Myanmar
# MNE  Montenegro
# MNG  Mongolia
# MNP  Northern Mariana Islands
# MOZ  Mozambique
# MRT  Mauritania
# MSR  Montserrat
# MTQ  Martinique
# MUS  Mauritius
# MWI  Malawi
# MYS  Malaysia
# MYT  Mayotte
# NAM  Namibia
# NCL  New Caledonia
# NER  Niger
# NFK  Norfolk Island
# NGA  Nigeria
# NIC  Nicaragua
# NIU  Niue
# NLD  Netherlands
# NOR  Norway
# NPL  Nepal
# NRU  Nauru
# NZL  New Zealand
# OMN  Oman
# PAK  Pakistan
# PAN  Panama
# PCN  Pitcairn
# PER  Peru
# PHL  Philippines
# PLW  Palau
# PNG  Papua New Guinea
# POL  Poland
# PRI  Puerto Rico
# PRK  Korea (Democratic People's Republic of)
# PRT  Portugal
# PRY  Paraguay
# PSE  Palestine, State of
# PYF  French Polynesia
# QAT  Qatar
# REU  Réunion
# ROU  Romania
# RUS  Russian Federation
# RWA  Rwanda
# SAU  Saudi Arabia
# SDN  Sudan
# SEN  Senegal
# SGP  Singapore
# SGS  South Georgia and the South Sandwich Islands
# SHN  Saint Helena, Ascension and Tristan da Cunha
# SJM  Svalbard and Jan Mayen
# SLB  Solomon Islands
# SLE  Sierra Leone
# SLV  El Salvador
# SMR  San Marino
# SOM  Somalia
# SPM  Saint Pierre and Miquelon
# SRB  Serbia
# SSD  South Sudan
# STP  Sao Tome and Principe
# SUR  Suriname
# SVK  Slovakia
# SVN  Slovenia
# SWE  Sweden
# SWZ  Eswatini
# SXM  Sint Maarten (Dutch part)
# SYC  Seychelles
# SYR  Syrian Arab Republic
# TCA  Turks and Caicos Islands
# TCD  Chad
# TGO  Togo
# THA  Thailand
# TJK  Tajikistan
# TKL  Tokelau
# TKM  Turkmenistan
# TLS  Timor-Leste
# TON  Tonga
# TTO  Trinidad and Tobago
# TUN  Tunisia
# TUR  Turkey
# TUV  Tuvalu
# TWN  Taiwan, Province of China
# TZA  Tanzania, United Republic of
# UGA  Uganda
# UKR  Ukraine
# UMI  United States Minor Outlying Islands
# URY  Uruguay
# USA  United States of America
# UZB  Uzbekistan
# VAT  Holy See
# VCT  Saint Vincent and the Grenadines
# VEN  Venezuela (Bolivarian Republic of)
# VGB  Virgin Islands (British)
# VIR  Virgin Islands (U.S.)
# VNM  Viet Nam
# VUT  Vanuatu
# WLF  Wallis and Futuna
# WSM  Samoa
# YEM  Yemen
# ZAF  South Africa
# ZMB  Zambia
# ZWE  Zimbabwe

# %%
leslie
# Out:
# ['ABW',
#  'Aruba',
#  'AFG',
#  'Afghanistan',
#  'AGO',
#  'Angola',
#  'AIA',
#  'Anguilla',
#  'ALA',
#  'Åland Islands',
#  'ALB',
#  'Albania',
#  'AND',
#  'Andorra',
#  'ARE',
#  'United Arab Emirates',
#  'ARG',
#  'Argentina',
#  'ARM',
#  'Armenia',
#  'ASM',
#  'American Samoa',
#  'ATA',
#  'Antarctica',
#  'ATF',
#  'French Southern Territories',
#  'ATG',
#  'Antigua and Barbuda',
#  'AUS',
#  'Australia',
#  'AUT',
#  'Austria',
#  'AZE',
#  'Azerbaijan',
#  'BDI',
#  'Burundi',
#  'BEL',
#  'Belgium',
#  'BEN',
#  'Benin',
#  'BES',
#  'Bonaire, Sint Eustatius and Saba',
#  'BFA',
#  'Burkina Faso',
#  'BGD',
#  'Bangladesh',
#  'BGR',
#  'Bulgaria',
#  'BHR',
#  'Bahrain',
#  'BHS',
#  'Bahamas',
#  'BIH',
#  'Bosnia and Herzegovina',
#  'BLM',
#  'Saint Barthélemy',
#  'BLR',
#  'Belarus',
#  'BLZ',
#  'Belize',
#  'BMU',
#  'Bermuda',
#  'BOL',
#  'Bolivia (Plurinational State of)',
#  'BRA',
#  'Brazil',
#  'BRB',
#  'Barbados',
#  'BRN',
#  'Brunei Darussalam',
#  'BTN',
#  'Bhutan',
#  'BVT',
#  'Bouvet Island',
#  'BWA',
#  'Botswana',
#  'CAF',
#  'Central African Republic',
#  'CAN',
#  'Canada',
#  'CCK',
#  'Cocos (Keeling) Islands',
#  'CHE',
#  'Switzerland',
#  'CHL',
#  'Chile',
#  'CHN',
#  'China',
#  'CIV',
#  "Côte d'Ivoire",
#  'CMR',
#  'Cameroon',
#  'COD',
#  'Congo, Democratic Republic of the',
#  'COG',
#  'Congo',
#  'COK',
#  'Cook Islands',
#  'COL',
#  'Colombia',
#  'COM',
#  'Comoros',
#  'CPV',
#  'Cabo Verde',
#  'CRI',
#  'Costa Rica',
#  'CUB',
#  'Cuba',
#  'CUW',
#  'Curaçao',
#  'CXR',
#  'Christmas Island',
#  'CYM',
#  'Cayman Islands',
#  'CYP',
#  'Cyprus',
#  'CZE',
#  'Czechia',
#  'DEU',
#  'Germany',
#  'DJI',
#  'Djibouti',
#  'DMA',
#  'Dominica',
#  'DNK',
#  'Denmark',
#  'DOM',
#  'Dominican Republic',
#  'DZA',
#  'Algeria',
#  'ECU',
#  'Ecuador',
#  'EGY',
#  'Egypt',
#  'ERI',
#  'Eritrea',
#  'ESH',
#  'Western Sahara',
#  'ESP',
#  'Spain',
#  'EST',
#  'Estonia',
#  'ETH',
#  'Ethiopia',
#  'FIN',
#  'Finland',
#  'FJI',
#  'Fiji',
#  'FLK',
#  'Falkland Islands (Malvinas)',
#  'FRA',
#  'France',
#  'FRO',
#  'Faroe Islands',
#  'FSM',
#  'Micronesia (Federated States of)',
#  'GAB',
#  'Gabon',
#  'GBR',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'GEO',
#  'Georgia',
#  'GGY',
#  'Guernsey',
#  'GHA',
#  'Ghana',
#  'GIB',
#  'Gibraltar',
#  'GIN',
#  'Guinea',
#  'GLP',
#  'Guadeloupe',
#  'GMB',
#  'Gambia',
#  'GNB',
#  'Guinea-Bissau',
#  'GNQ',
#  'Equatorial Guinea',
#  'GRC',
#  'Greece',
#  'GRD',
#  'Grenada',
#  'GRL',
#  'Greenland',
#  'GTM',
#  'Guatemala',
#  'GUF',
#  'French Guiana',
#  'GUM',
#  'Guam',
#  'GUY',
#  'Guyana',
#  'HKG',
#  'Hong Kong',
#  'HMD',
#  'Heard Island and McDonald Islands',
#  'HND',
#  'Honduras',
#  'HRV',
#  'Croatia',
#  'HTI',
#  'Haiti',
#  'HUN',
#  'Hungary',
#  'IDN',
#  'Indonesia',
#  'IMN',
#  'Isle of Man',
#  'IND',
#  'India',
#  'IOT',
#  'British Indian Ocean Territory',
#  'IRL',
#  'Ireland',
#  'IRN',
#  'Iran (Islamic Republic of)',
#  'IRQ',
#  'Iraq',
#  'ISL',
#  'Iceland',
#  'ISR',
#  'Israel',
#  'ITA',
#  'Italy',
#  'JAM',
#  'Jamaica',
#  'JEY',
#  'Jersey',
#  'JOR',
#  'Jordan',
#  'JPN',
#  'Japan',
#  'KAZ',
#  'Kazakhstan',
#  'KEN',
#  'Kenya',
#  'KGZ',
#  'Kyrgyzstan',
#  'KHM',
#  'Cambodia',
#  'KIR',
#  'Kiribati',
#  'KNA',
#  'Saint Kitts and Nevis',
#  'KOR',
#  'Korea, Republic of',
#  'KWT',
#  'Kuwait',
#  'LAO',
#  "Lao People's Democratic Republic",
#  'LBN',
#  'Lebanon',
#  'LBR',
#  'Liberia',
#  'LBY',
#  'Libya',
#  'LCA',
#  'Saint Lucia',
#  'LIE',
#  'Liechtenstein',
#  'LKA',
#  'Sri Lanka',
#  'LSO',
#  'Lesotho',
#  'LTU',
#  'Lithuania',
#  'LUX',
#  'Luxembourg',
#  'LVA',
#  'Latvia',
#  'MAC',
#  'Macao',
#  'MAF',
#  'Saint Martin (French part)',
#  'MAR',
#  'Morocco',
#  'MCO',
#  'Monaco',
#  'MDA',
#  'Moldova, Republic of',
#  'MDG',
#  'Madagascar',
#  'MDV',
#  'Maldives',
#  'MEX',
#  'Mexico',
#  'MHL',
#  'Marshall Islands',
#  'MKD',
#  'North Macedonia',
#  'MLI',
#  'Mali',
#  'MLT',
#  'Malta',
#  'MMR',
#  'Myanmar',
#  'MNE',
#  'Montenegro',
#  'MNG',
#  'Mongolia',
#  'MNP',
#  'Northern Mariana Islands',
#  'MOZ',
#  'Mozambique',
#  'MRT',
#  'Mauritania',
#  'MSR',
#  'Montserrat',
#  'MTQ',
#  'Martinique',
#  'MUS',
#  'Mauritius',
#  'MWI',
#  'Malawi',
#  'MYS',
#  'Malaysia',
#  'MYT',
#  'Mayotte',
#  'NAM',
#  'Namibia',
#  'NCL',
#  'New Caledonia',
#  'NER',
#  'Niger',
#  'NFK',
#  'Norfolk Island',
#  'NGA',
#  'Nigeria',
#  'NIC',
#  'Nicaragua',
#  'NIU',
#  'Niue',
#  'NLD',
#  'Netherlands',
#  'NOR',
#  'Norway',
#  'NPL',
#  'Nepal',
#  'NRU',
#  'Nauru',
#  'NZL',
#  'New Zealand',
#  'OMN',
#  'Oman',
#  'PAK',
#  'Pakistan',
#  'PAN',
#  'Panama',
#  'PCN',
#  'Pitcairn',
#  'PER',
#  'Peru',
#  'PHL',
#  'Philippines',
#  'PLW',
#  'Palau',
#  'PNG',
#  'Papua New Guinea',
#  'POL',
#  'Poland',
#  'PRI',
#  'Puerto Rico',
#  'PRK',
#  "Korea (Democratic People's Republic of)",
#  'PRT',
#  'Portugal',
#  'PRY',
#  'Paraguay',
#  'PSE',
#  'Palestine, State of',
#  'PYF',
#  'French Polynesia',
#  'QAT',
#  'Qatar',
#  'REU',
#  'Réunion',
#  'ROU',
#  'Romania',
#  'RUS',
#  'Russian Federation',
#  'RWA',
#  'Rwanda',
#  'SAU',
#  'Saudi Arabia',
#  'SDN',
#  'Sudan',
#  'SEN',
#  'Senegal',
#  'SGP',
#  'Singapore',
#  'SGS',
#  'South Georgia and the South Sandwich Islands',
#  'SHN',
#  'Saint Helena, Ascension and Tristan da Cunha',
#  'SJM',
#  'Svalbard and Jan Mayen',
#  'SLB',
#  'Solomon Islands',
#  'SLE',
#  'Sierra Leone',
#  'SLV',
#  'El Salvador',
#  'SMR',
#  'San Marino',
#  'SOM',
#  'Somalia',
#  'SPM',
#  'Saint Pierre and Miquelon',
#  'SRB',
#  'Serbia',
#  'SSD',
#  'South Sudan',
#  'STP',
#  'Sao Tome and Principe',
#  'SUR',
#  'Suriname',
#  'SVK',
#  'Slovakia',
#  'SVN',
#  'Slovenia',
#  'SWE',
#  'Sweden',
#  'SWZ',
#  'Eswatini',
#  'SXM',
#  'Sint Maarten (Dutch part)',
#  'SYC',
#  'Seychelles',
#  'SYR',
#  'Syrian Arab Republic',
#  'TCA',
#  'Turks and Caicos Islands',
#  'TCD',
#  'Chad',
#  'TGO',
#  'Togo',
#  'THA',
#  'Thailand',
#  'TJK',
#  'Tajikistan',
#  'TKL',
#  'Tokelau',
#  'TKM',
#  'Turkmenistan',
#  'TLS',
#  'Timor-Leste',
#  'TON',
#  'Tonga',
#  'TTO',
#  'Trinidad and Tobago',
#  'TUN',
#  'Tunisia',
#  'TUR',
#  'Turkey',
#  'TUV',
#  'Tuvalu',
#  'TWN',
#  'Taiwan',
#  'Province of China',
#  'TZA',
#  'Tanzania, United Republic of',
#  'UGA',
#  'Uganda',
#  'UKR',
#  'Ukraine',
#  'UMI',
#  'United States Minor Outlying Islands',
#  'URY',
#  'Uruguay',
#  'USA',
#  'United States of America',
#  'UZB',
#  'Uzbekistan',
#  'VAT',
#  'Holy See',
#  'VCT',
#  'Saint Vincent and the Grenadines',
#  'VEN',
#  'Venezuela (Bolivarian Republic of)',
#  'VGB',
#  'Virgin Islands (British)',
#  'VIR',
#  'Virgin Islands (U.S.)',
#  'VNM',
#  'Viet Nam',
#  'VUT',
#  'Vanuatu',
#  'WLF',
#  'Wallis and Futuna',
#  'WSM',
#  'Samoa',
#  'YEM',
#  'Yemen',
#  'ZAF',
#  'South Africa',
#  'ZMB',
#  'Zambia',
#  'ZWE',
#  'Zimbabwe']

# %%
# # df["Nationality"].values.tolist()[::-1]

# index

# df["Nationality"][31]

# code

# index = country_codes["Alpha-3 code"].values.tolist().index("GBR")
# index

# country_codes["Country"].values.tolist().index("Great Britain")

# code = country_codes["Alpha-3 code"][index]
# code

# %%
df["Nationality"][::-1].head()
# Out:
# 10198     Brazil
# 10197    Morocco
# 10196     Turkey
# 10195    Moldova
# 10194      Samoa
# Name: Nationality, dtype: object

# %%
df["Nationality"][::-1].head()
# Out:
# 10198     Brazil
# 10197    Morocco
# 10196     Turkey
# 10195    Moldova
# 10194      Samoa
# Name: Nationality, dtype: object

# %%
df.head()
# Out:
#    Year Event Gender  Comp Rank       Athlete Name Nationality Group  \
# 0  1996   iwf      W        1.0             Wan Ni         CHN     A
# 1  1996   iwf      W        2.0  Karoliina Lundahl         FIN     A
# 2  1996   iwf      W        3.0    Chen Hsiao-lien         TPE     A
# 3  1996   iwf      W        4.0       Sylvie Iskin         FRA     A
# 4  1996   iwf      W        5.0    Erika TakÃƒÂ¡cs         HUN     A
#
#    Body Weight (kg)  Snatch 1 (kg)  Snatch 2 (kg)  Snatch 3 (kg)  Max Snatch  \
# 0             84.40          102.5         -107.5         -110.0       102.5
# 1             83.10          100.0          105.0          107.5       107.5
# 2            100.40          -95.0          -97.5           97.5        97.5
# 3             96.85         -100.0          100.0          102.5       102.5
# 4             96.00           97.5         -100.0         -100.0        97.5
#
#    Snatch Rank  C/J 1 (kg)  C/J 2 (kg)  C/J 3 (kg)  Max C/J  C/J Rank  Total
# 0            2       130.0       135.0       137.5    137.5         1  240.0
# 1            1       125.0      -127.5      -127.5    125.0         3  232.5
# 2            4       130.0      -137.5      -137.5    130.0         2  227.5
# 3            2       117.5      -122.5       122.5    122.5         4  225.0
# 4            4       120.0      -125.0      -125.0    120.0         5  217.5

# %%
len(code_list)
# Out:
# 10199

# %%
code_list
# Out:
# ['CHN',
#  'FIN',
#  'TPE',
#  'FRA',
#  'HUN',
#  'GRE',
#  'USA',
#  'CHN',
#  'IND',
#  'TPE',
#  'JPN',
#  'BUL',
#  'RUS',
#  'USA',
#  'CHN',
#  'KOR',
#  'TPE',
#  'BUL',
#  'GRE',
#  'JPN',
#  'BUL',
#  'HUN',
#  'HUN',
#  'AUS',
#  'CHN',
#  'TPE',
#  'IND',
#  'BUL',
#  'CAN',
#  'RUS',
#  'GRE',
#  'ITA',
#  'USA',
#  'FRA',
#  'MEX',
#  'FIN',
#  'HUN',
#  'USA',
#  'CHN',
#  'GRE',
#  'JPN',
#  'CAN',
#  'ESP',
#  'CZE',
#  'RUS',
#  'POL',
#  'COL',
#  'FIN',
#  'BUL',
#  'TPE',
#  'BUL',
#  'GRE',
#  'CHN',
#  'TPE',
#  'TPE',
#  'FRA',
#  'KOR',
#  'RUS',
#  'IND',
#  'IND',
#  'GRE',
#  'USA',
#  'ITA',
#  'GBR',
#  'USA',
#  'BLR',
#  'POL',
#  'BUL',
#  'CHN',
#  'RUS',
#  'KOR',
#  'HUN',
#  'RUS',
#  'JPN',
#  'TPE',
#  'GRE',
#  'CZE',
#  'FIN',
#  'AUS',
#  'USA',
#  'CZE',
#  'ESP',
#  'CHN',
#  'HUN',
#  'GRE',
#  'CAN',
#  'RUS',
#  'IND',
#  'USA',
#  'ESP',
#  'GRE',
#  'USA',
#  'COL',
#  'TUR',
#  'CHN',
#  'TPE',
#  'COL',
#  'GER',
#  'FRA',
#  'JPN',
#  'AUS',
#  'RUS',
#  'RUS',
#  'GER',
#  'LAT',
#  'HUN',
#  'SWE',
#  'LAT',
#  'NOR',
#  'ARM',
#  'TUR',
#  'ESP',
#  'IRQ',
#  'CZE',
#  'TPE',
#  'THA',
#  'NRU',
#  'RUS',
#  'AUT',
#  'CHN',
#  'POL',
#  'USA',
#  'GER',
#  'JPN',
#  'ITA',
#  'KOR',
#  'LAT',
#  'RUS',
#  'RUS',
#  'GBR',
#  'CHN',
#  'CHN',
#  'TPE',
#  'BUL',
#  'JPN',
#  'ROU',
#  'EGY',
#  'FRA',
#  'TPE',
#  'AUS',
#  'JPN',
#  'THA',
#  'BUL',
#  'CHN',
#  'BUL',
#  'CUB',
#  'AZE',
#  'AUS',
#  'TUR',
#  'THA',
#  'EGY',
#  'JPN',
#  'TPE',
#  'KAZ',
#  'TPE',
#  'THA',
#  'VEN',
#  'BEL',
#  'JPN',
#  'FIN',
#  'ROU',
#  'CHN',
#  'TUR',
#  'AZE',
#  'BUL',
#  'TUR',
#  'JPN',
#  'EGY',
#  'NRU',
#  'MAS',
#  'MAS',
#  'CHN',
#  'ROU',
#  'HUN',
#  'BUL',
#  'CHN',
#  'CHN',
#  'TUR',
#  'KOR',
#  'AUT',
#  'TUR',
#  'SVK',
#  'HUN',
#  'BEL',
#  'EGY',
#  'ISR',
#  'DEN',
#  'CAN',
#  'AUS',
#  'NED',
#  'SUI',
#  'TPE',
#  'MDA',
#  'THA',
#  'ALG',
#  'PRK',
#  'BUL',
#  'BUL',
#  'POL',
#  'POL',
#  'UKR',
#  'RUS',
#  'GER',
#  'ARM',
#  'KOR',
#  'ARM',
#  'RUS',
#  'EGY',
#  'AUS',
#  'USA',
#  'ARG',
#  'KAZ',
#  'SWE',
#  'SVK',
#  'KAZ',
#  'AUS',
#  'TPE',
#  'THA',
#  'THA',
#  'URU',
#  'CUB',
#  'TUR',
#  'POL',
#  'TUR',
#  'POL',
#  'RUS',
#  'UKR',
#  'ITA',
#  'ITA',
#  'LAT',
#  'EGY',
#  'NZL',
#  'CZE',
#  'TPE',
#  'THA',
#  'CAN',
#  'AUS',
#  'NED',
#  'KGZ',
#  'CHN',
#  'UZB',
#  'KAZ',
#  'KAZ',
#  'RUS',
#  'POL',
#  'VEN',
#  'KAZ',
#  'GER',
#  'UKR',
#  'TUR',
#  'AUS',
#  'CHN',
#  'LAT',
#  'SVK',
#  'AUT',
#  'UZB',
#  'EGY',
#  'GBR',
#  'UZB',
#  'AUS',
#  'THA',
#  'AZE',
#  'IRQ',
#  'ITA',
#  'CUB',
#  'MDA',
#  'TUR',
#  'SVK',
#  'KOR',
#  'UKR',
#  'RUS',
#  'KAZ',
#  'CUB',
#  'ESP',
#  'GER',
#  'MDA',
#  'USA',
#  'FIN',
#  'UKR',
#  'CAN',
#  'ROU',
#  'FIN',
#  'CZE',
#  'CHI',
#  'THA',
#  'GBR',
#  'TPE',
#  'TPE',
#  'EGY',
#  'ARM',
#  'LTU',
#  'CHN',
#  'TPE',
#  'MYA',
#  'NGR',
#  'UKR',
#  'ESP',
#  'NOR',
#  'POL',
#  'NZL',
#  'GRE',
#  'NRU',
#  'USA',
#  'TPE',
#  'TUR',
#  'CHN',
#  'IND',
#  'INA',
#  'MYA',
#  'TPE',
#  'THA',
#  'VEN',
#  'THA',
#  'RUS',
#  'ITA',
#  'ARG',
#  'INA',
#  'BUL',
#  'PRK',
#  'TPE',
#  'MYA',
#  'IND',
#  'JPN',
#  'USA',
#  'KOR',
#  'USA',
#  'JPN',
#  'THA',
#  'ESP',
#  'FRA',
#  'ESP',
#  'GRE',
#  'AUS',
#  'EGY',
#  'TUR',
#  'CHN',
#  'THA',
#  'CHN',
#  'PRK',
#  'THA',
#  'BUL',
#  'CAN',
#  'MYA',
#  'THA',
#  'IND',
#  'SVK',
#  'JPN',
#  'USA',
#  'ESP',
#  'VEN',
#  'MEX',
#  'ITA',
#  'NED',
#  'EGY',
#  'TPE',
#  'ROU',
#  'INA',
#  'THA',
#  'MYA',
#  'TPE',
#  'IND',
#  'CAN',
#  'POL',
#  'IND',
#  'ESP',
#  'RUS',
#  'ITA',
#  'UZB',
#  'VEN',
#  'RUS',
#  'CZE',
#  'TUR',
#  'NRU',
#  'CHN',
#  'TPE',
#  'IND',
#  'THA',
#  'THA',
#  'CHN',
#  'HUN',
#  'KOR',
#  'RUS',
#  'USA',
#  'GRE',
#  'FRA',
#  'ITA',
#  'IND',
#  'AUS',
#  'GBR',
#  'ROU',
#  'MYA',
#  'CHN',
#  'TPE',
#  'HUN',
#  'RUS',
#  'MYA',
#  'PRK',
#  'JPN',
#  'CAN',
#  'KOR',
#  'RUS',
#  'EGY',
#  'GRE',
#  'TUR',
#  'GBR',
#  'GRE',
#  'CHN',
#  'HUN',
#  'KOR',
#  'PRK',
#  'IND',
#  'FRA',
#  'IND',
#  'ESP',
#  'CAN',
#  'JPN',
#  'ITA',
#  'TPE',
#  'MYA',
#  'TUR',
#  'NGR',
#  'UKR',
#  'CHN',
#  'COL',
#  'MYA',
#  'RUS',
#  'GER',
#  'FIN',
#  'AUS',
#  'TUR',
#  'GRE',
#  'SVK',
#  'NRU',
#  'TUR',
#  'RUS',
#  'ARM',
#  'LAT',
#  'POL',
#  'GRE',
#  'GER',
#  'ESP',
#  'ESP',
#  'NZL',
#  'JPN',
#  'EGY',
#  'TPE',
#  'CMR',
#  'ALG',
#  'LTU',
#  'NRU',
#  'NED',
#  'ARM',
#  'HUN',
#  'SWE',
#  'UKR',
#  'CHN',
#  'UKR',
#  'RUS',
#  'SVK',
#  'RUS',
#  'BLR',
#  'GEO',
#  'GER',
#  'HUN',
#  'TUR',
#  'FIN',
#  'ITA',
#  'JPN',
#  'LAT',
#  'GER',
#  'CAN',
#  'COL',
#  'CZE',
#  'ROU',
#  'AZE',
#  'FRA',
#  'CRO',
#  'POL',
#  'GBR',
#  'ESP',
#  'POL',
#  'FIN',
#  'TUR',
#  'CHN',
#  'BUL',
#  'CUB',
#  'ROU',
#  'ROU',
#  'FRA',
#  'HUN',
#  'JPN',
#  'EGY',
#  'FRA',
#  'ALG',
#  'CAN',
#  'ISR',
#  'COL',
#  'ISR',
#  'GRE',
#  'CRO',
#  'BUL',
#  'CHN',
#  'CHN',
#  'BUL',
#  'HUN',
#  'MDA',
#  'TUR',
#  'AUS',
#  'NRU',
#  'KAZ',
#  'COL',
#  'ESP',
#  'FIN',
#  'FRA',
#  'BEL',
#  'TPE',
#  'POR',
#  'IRE',
#  'UGA',
#  'FRA',
#  'EGY',
#  'FIN',
#  'BUL',
#  'GRE',
#  'CHN',
#  'BUL',
#  'GRE',
#  'RUS',
#  'BLR',
#  'CHN',
#  'ROU',
#  'BEL',
#  'TUR',
#  'HUN',
#  'JPN',
#  'CAN',
#  'AZE',
#  'ITA',
#  'AUT',
#  'EGY',
#  'COL',
#  'ALG',
#  'EGY',
#  'PAN',
#  'LAT',
#  'CZE',
#  'NED',
#  'UGA',
#  'TUR',
#  'HUN',
#  'AZE',
#  'FRA',
#  'DEN',
#  'BUL',
#  'BUL',
#  'TUR',
#  'GRE',
#  'GER',
#  'GEO',
#  'POL',
#  'ARM',
#  'CUB',
#  'ROU',
#  'BLR',
#  'ARM',
#  'USA',
#  'EGY',
#  'GER',
#  'SVK',
#  'ITA',
#  'CAN',
#  'TPE',
#  'CAN',
#  'ARG',
#  'NRU',
#  'SUI',
#  'CRO',
#  'RUS',
#  'HUN',
#  'CHN',
#  'GRE',
#  'GER',
#  'RUS',
#  'MDA',
#  'BUL',
#  'TUR',
#  'POL',
#  'AUS',
#  'EGY',
#  'GBR',
#  'AZE',
#  'SVK',
#  'ITA',
#  'COL',
#  'AZE',
#  'EGY',
#  'ESP',
#  'ITA',
#  'GBR',
#  'AUS',
#  'CAN',
#  'CAN',
#  'FIN',
#  'CRO',
#  'CRO',
#  'CHN',
#  'LAT',
#  'ECU',
#  'FIN',
#  'LAT',
#  'GRE',
#  'GER',
#  'GRE',
#  'POL',
#  'POL',
#  'TUR',
#  'VEN',
#  'ARM',
#  'RUS',
#  'UKR',
#  'BLR',
#  'GER',
#  'LAT',
#  'KAZ',
#  'DEN',
#  'FIN',
#  'FIN',
#  'TPE',
#  'AUS',
#  'GBR',
#  'AUS',
#  'NRU',
#  'CAN',
#  'CMR',
#  'CRO',
#  'NED',
#  'IRL',
#  'ROU',
#  'UKR',
#  'HUN',
#  'GBR',
#  'NOR',
#  'ISR',
#  'ECU',
#  'CHN',
#  'TPE',
#  'COL',
#  'POL',
#  'GER',
#  'UKR',
#  'NOR',
#  'UKR',
#  'ESP',
#  'HUN',
#  'FRA',
#  'CAN',
#  'NRU',
#  'CAN',
#  'DEN',
#  'NRU',
#  'CHN',
#  'TPE',
#  'TPE',
#  'JPN',
#  'BUL',
#  'USA',
#  'VEN',
#  'JPN',
#  'HUN',
#  'FRA',
#  'FRA',
#  'ITA',
#  'CAN',
#  'NRU',
#  'ITA',
#  'FIN',
#  'CHN',
#  'BUL',
#  'USA',
#  'ESP',
#  'VEN',
#  'SVK',
#  'GRE',
#  'ITA',
#  'AZE',
#  'SWE',
#  'EGY',
#  'EGY',
#  'ISR',
#  'NRU',
#  'USA',
#  'TPE',
#  'CHN',
#  'BUL',
#  'CAN',
#  'GRE',
#  'POL',
#  'FRA',
#  'VEN',
#  'CZE',
#  'POL',
#  'NED',
#  'GBR',
#  'MEX',
#  'FIN',
#  'NRU',
#  'FIN',
#  'CAN',
#  'TPE',
#  'CHN',
#  'RUS',
#  'POL',
#  'COL',
#  'ESP',
#  'CAN',
#  'ITA',
#  'HUN',
#  'KOR',
#  'AUS',
#  'FRA',
#  'HUN',
#  'VEN',
#  'GER',
#  'EGY',
#  'FIN',
#  'ISR',
#  'ARG',
#  'UGA',
#  'CHN',
#  'TPE',
#  'RUS',
#  'HUN',
#  'POL',
#  'BUL',
#  'KOR',
#  'USA',
#  'GER',
#  'FIN',
#  'GRE',
#  'USA',
#  'AUS',
#  'DEN',
#  'NOR',
#  'EGY',
#  'FIN',
#  'TUR',
#  'HUN',
#  'USA',
#  'ESP',
#  'CZE',
#  'FRA',
#  'CAN',
#  'ITA',
#  'AUS',
#  'RUS',
#  'JPN',
#  'GRE',
#  'COL',
#  'GRE',
#  'FIN',
#  'GBR',
#  'SVK',
#  'NRU',
#  'HUN',
#  'TPE',
#  'CHN',
#  'RUS',
#  'QAT',
#  'IRI',
#  'KOR',
#  'UKR',
#  'LAT',
#  'NOR',
#  'RUS',
#  'UKR',
#  'BLR',
#  'GER',
#  'HUN',
#  'UZB',
#  'POL',
#  'USA',
#  'POL',
#  'ESP',
#  'LAT',
#  'ESP',
#  'FIN',
#  'GEO',
#  'GBR',
#  'FRA',
#  'EGY',
#  'IND',
#  'NZL',
#  'SYR',
#  'LTU',
#  'GEO',
#  'PUR',
#  'CUB',
#  'AUT',
#  'CZE',
#  'GBR',
#  'IRQ',
#  'ALG',
#  'LTU',
#  'NED',
#  'DEN',
#  'NED',
#  'ARM',
#  'FIN',
#  'GER',
#  'ARM',
#  'JPN',
#  'DEN',
#  'AUT',
#  'AZE',
#  'UKR',
#  'RUS',
#  'KOR',
#  'GEO',
#  'IRI',
#  'MDA',
#  'POL',
#  'POL',
#  'TUR',
#  'KAZ',
#  'QAT',
#  'HUN',
#  'ROU',
#  'AZE',
#  'USA',
#  'JPN',
#  'ITA',
#  'GER',
#  'BLR',
#  'ITA',
#  'LAT',
#  'AUT',
#  'EGY',
#  'GBR',
#  'TUN',
#  'CHI',
#  'TPE',
#  'DEN',
#  'DOM',
#  'NGR',
#  'NED',
#  'CAN',
#  'CYP',
#  'GER',
#  'GEO',
#  'FIN',
#  'IRL',
#  'GBR',
#  'ESP',
#  'KAZ',
#  'UKR',
#  'TUR',
#  'ROU',
#  'TPE',
#  'BUL',
#  'CHN',
#  'CUB',
#  'UKR',
#  'CHN',
#  'TPE',
#  'KOR',
#  'FRA',
#  'JPN',
#  'MDA',
#  'COL',
#  'JPN',
#  'VEN',
#  'GUA',
#  'UZB',
#  'EGY',
#  'HUN',
#  'FSM',
#  'COL',
#  'ALG',
#  'LAT',
#  'FRA',
#  'ESP',
#  'ESA',
#  'ISR',
#  'ESP',
#  'NRU',
#  'RSA',
#  'ITA',
#  'NGR',
#  'FIN',
#  'BLR',
#  'CHN',
#  'GRE',
#  'BUL',
#  'CHN',
#  'CRO',
#  'BLR',
#  'NRU',
#  'JPN',
#  'TUR',
#  'MDA',
#  'HUN',
#  'AUS',
#  'KOR',
#  'AZE',
#  'ROU',
#  'KSA',
#  'JPN',
#  'KAZ',
#  'QAT',
#  'TUN',
#  'COL',
#  'BEL',
#  'IRI',
#  'EGY',
#  'GEO',
#  'VEN',
#  'FRA',
#  'USA',
#  'FRA',
#  'COL',
#  'ALB',
#  'ITA',
#  'IRQ',
#  'IRL',
#  'GUA',
#  'LTU',
#  'GUA',
#  'LBN',
#  'BUL',
#  'TKM',
#  'CMR',
#  'AZE',
#  'ALB',
#  'TKM',
#  'BUL',
#  'GRE',
#  'GRE',
#  'ROU',
#  'CHN',
#  'BLR',
#  'TUR',
#  'QAT',
#  'ARM',
#  'KOR',
#  'RUS',
#  'ARM',
#  'ROU',
#  'AZE',
#  'ITA',
#  'BEL',
#  'JPN',
#  'IRI',
#  'INA',
#  'AZE',
#  'SVK',
#  'DEN',
#  'EGY',
#  'ALG',
#  'IRI',
#  'KGZ',
#  'COL',
#  'COL',
#  'CAN',
#  'ALG',
#  'SVK',
#  'TPE',
#  'LTU',
#  'RSA',
#  'NED',
#  'IRL',
#  'QAT',
#  'FRA',
#  'SWE',
#  'CHN',
#  'PAN',
#  'QAT',
#  'GRE',
#  'BUL',
#  'CHN',
#  'QAT',
#  'ARM',
#  'ARM',
#  'UKR',
#  'BUL',
#  'KAZ',
#  'TUR',
#  'HUN',
#  'TUR',
#  'KOR',
#  'CHN',
#  'KOR',
#  'RUS',
#  'GER',
#  'CUB',
#  'ROU',
#  'USA',
#  'ECU',
#  'KGZ',
#  'SVK',
#  'ALB',
#  ...]

# %%
df["Nationality"] = code_list

# %%
df["Nationality"]
# Out:
# 0                  CHN
# 1                  FIN
# 2                  TPE
# 3                  FRA
# 4                  HUN
# 5                  GRE
# 6                  USA
# 7                  CHN
# 8                  IND
# 9                  TPE
# 10                 JPN
# 11                 BUL
# 12                 RUS
# 13                 USA
# 14                 CHN
# 15                 KOR
# 16                 TPE
# 17                 BUL
# 18                 GRE
# 19                 JPN
# 20                 BUL
# 21                 HUN
# 22                 HUN
# 23                 AUS
# 24                 CHN
# 25                 TPE
# 26                 IND
# 27                 BUL
# 28                 CAN
# 29                 RUS
#              ...
# 10169              EGY
# 10170              COL
# 10171              ARM
# 10172              BLR
# 10173              ECU
# 10174              MNG
# 10175              CAN
# 10176    Great Britain
# 10177              FJI
# 10178              TUR
# 10179              TKM
# 10180              CMR
# 10181              POL
# 10182              ROU
# 10183              BLR
# 10184      North Korea
# 10185              BLR
# 10186              ESP
# 10187              COL
# 10188              UKR
# 10189    United States
# 10190              CHL
# 10191              FRA
# 10192              MEX
# 10193              ARM
# 10194              WSM
# 10195          Moldova
# 10196              TUR
# 10197              MAR
# 10198              BRA
# Name: Nationality, Length: 10199, dtype: object

# %%
"""Working copy. Need to find non Alpha 3 code countries. """
code_list = []

for country in df["Nationality"].values.tolist():
    if country in country_codes["Country"].values.tolist():
        index = country_codes["Country"].values.tolist().index(country)
        code = country_codes["Alpha-3 code"][index]
        code_list.append(code)
#         df["Nationality"][index] = code_list[index]
    else:
        index = df["Nationality"].values.tolist().index(country)
        code = df["Nationality"].values.tolist()[index]
        code_list.append(code)
df["Nationality"][index] = code_list[index]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
"""Testing copy. """
code_list = []
# remaining = []
for country in df["Nationality"].values.tolist():
    if country in country_codes["Country"].values.tolist():
        index = country_codes["Country"].values.tolist().index(country)
        code = country_codes["Alpha-3 code"][index]
        code_list.append(code)
#         df["Nationality"][index] = code_list[index]
#     elif country not in country_codes["Alpha-3 code"].values.tolist():
#         index = df["Nationality"].values.tolist().index(country)
#         code = df["Nationality"].values.tolist()[index]
#         remaining.append(code)
df["Nationality"][index] = code_list[index]

# %%
if df["Nationality"].values.tolist() not in country_codes["Alpha-3 code"].values.tolist():
    print("yes")
# Out:
# yes

# %%
"INA" in country_codes["Alpha-3 code"].values.tolist()
# Out:
# False

# %%
for country in df["Nationality"].values.tolist():
    if not country in country_codes["Alpha-3 code"].values.tolist() and not country in country_codes["Country"].values.tolist():
        print(f"{country}")
# Out:
# TPE
# GRE
# TPE
# BUL
# TPE
# BUL
# GRE
# BUL
# TPE
# BUL
# GRE
# GRE
# BUL
# TPE
# BUL
# GRE
# TPE
# TPE
# GRE
# BUL
# TPE
# GRE
# GRE
# GRE
# TPE
# GER
# GER
# LAT
# LAT
# TPE
# GER
# LAT
# TPE
# BUL
# TPE
# BUL
# BUL
# TPE
# TPE
# BUL
# MAS
# MAS
# BUL
# DEN
# NED
# SUI
# TPE
# ALG
# BUL
# BUL
# GER
# TPE
# URU
# LAT
# TPE
# NED
# GER
# LAT
# GER
# CHI
# TPE
# TPE
# TPE
# MYA
# NGR
# GRE
# TPE
# INA
# MYA
# TPE
# INA
# BUL
# TPE
# MYA
# GRE
# BUL
# MYA
# NED
# TPE
# INA
# MYA
# TPE
# TPE
# GRE
# MYA
# TPE
# MYA
# GRE
# GRE
# TPE
# MYA
# NGR
# MYA
# GER
# GRE
# LAT
# GRE
# GER
# TPE
# ALG
# NED
# GER
# LAT
# GER
# CRO
# BUL
# ALG
# GRE
# CRO
# BUL
# BUL
# TPE
# POR
# IRE
# BUL
# GRE
# BUL
# GRE
# ALG
# LAT
# NED
# DEN
# BUL
# BUL
# GRE
# GER
# GER
# TPE
# SUI
# CRO
# GRE
# GER
# BUL
# CRO
# CRO
# LAT
# LAT
# GRE
# GER
# GRE
# GER
# LAT
# DEN
# TPE
# CRO
# NED
# TPE
# GER
# DEN
# TPE
# TPE
# BUL
# BUL
# GRE
# TPE
# BUL
# GRE
# NED
# TPE
# GER
# TPE
# BUL
# GER
# GRE
# DEN
# GRE
# GRE
# TPE
# IRI
# LAT
# GER
# LAT
# PUR
# ALG
# NED
# DEN
# NED
# GER
# DEN
# IRI
# GER
# LAT
# CHI
# TPE
# DEN
# NGR
# NED
# GER
# TPE
# BUL
# TPE
# GUA
# ALG
# LAT
# ESA
# RSA
# NGR
# GRE
# BUL
# CRO
# KSA
# IRI
# GUA
# GUA
# BUL
# BUL
# GRE
# GRE
# IRI
# INA
# DEN
# ALG
# IRI
# ALG
# TPE
# RSA
# NED
# GRE
# BUL
# BUL
# GER
# NGR
# LAT
# NED
# GUA
# TPE
# POR
# SAM
# POR
# SUI
# IRI
# NED
# IRI
# GRE
# GER
# GRE
# BUL
# GER
# LAT
# LAT
# SAM
# CRO
# TPE
# SUI
# SUI
# GUA
# URU
# DEN
# DEN
# NED
# GRE
# GRE
# BUL
# IRI
# GER
# LAT
# TPE
# DEN
# DEN
# SUI
# SUI
# LBA
# POR
# NGR
# NGR
# DEN
# TPE
# BUL
# INA
# MYA
# INA
# TPE
# MYA
# POR
# NED
# TPE
# INA
# INA
# MYA
# NGR
# BUL
# BUL
# GRE
# DEN
# POR
# POR
# TPE
# BUL
# MYA
# NGR
# MGL
# ESA
# GRE
# POR
# DEN
# DEN
# NED
# ALG
# NED
# TPE
# GRE
# NGR
# BUL
# GER
# FIJ
# NED
# DEN
# ALG
# DEN
# PUR
# BUL
# BUL
# GRE
# NGR
# ESA
# PUR
# DEN
# NED
# TPE
# GRE
# NGR
# TPE
# MYA
# GER
# GRE
# GER
# GRE
# MRI
# GER
# CHI
# BUL
# BUL
# GER
# GRE
# GER
# SUI
# CRO
# IRI
# TPE
# BUL
# CRO
# BUL
# GRE
# NGR
# ALG
# IRI
# BUL
# BUL
# GRE
# GRE
# SUI
# IRI
# GER
# BUL
# IRI
# BUL
# GRE
# GER
# TPE
# NGR
# GRE
# GRE
# NGR
# TPE
# TPE
# NGR
# BUL
# MGL
# DEN
# GRE
# TPE
# BUL
# ALG
# TPE
# GRE
# NED
# TPE
# NGR
# GRE
# GRE
# IRI
# BUL
# GER
# CHI
# BUL
# IRI
# GER
# GER
# CRO
# TPE
# TPE
# GRE
# BUL
# GRE
# CRO
# GRE
# TPE
# LAT
# IRI
# IRI
# BUL
# BUL
# IRI
# IRI
# BUL
# LAT
# BUL
# IRI
# LAT
# GRE
# GRE
# BUL
# GER
# GRE
# NED
# LAT
# IRI
# GRE
# GER
# GRE
# BUL
# TPE
# BUL
# TPE
# TPE
# GRE
# BUL
# TPE
# ALG
# DEN
# GRE
# BUL
# BUL
# ALG
# GRE
# LAT
# IRI
# BUL
# LAT
# BUL
# ALG
# GER
# GER
# GER
# IRI
# GER
# SUI
# BUL
# TPE
# INA
# TPE
# KSA
# ALG
# INA
# GRE
# ESA
# INA
# KSA
# TPE
# KSA
# ESA
# TPE
# INA
# CRO
# INA
# IRI
# KSA
# KSA
# IRI
# BUL
# GER
# GER
# ALG
# TPE
# IRI
# IRI
# KSA
# BUL
# PUR
# SUI
# BUL
# BUL
# IRI
# GER
# KSA
# NED
# GER
# KSA
# PUR
# GRE
# BUL
# GRE
# NGR
# BUL
# INA
# TPE
# GRE
# TPE
# NGR
# ESA
# INA
# NGR
# INA
# INA
# INA
# NGR
# GRE
# PUR
# TPE
# BUL
# BUL
# ALG
# NGR
# TPE
# PUR
# BUL
# TPE
# ESA
# BUL
# TPE
# BUL
# NGR
# TPE
# GER
# NGR
# IRI
# LAT
# GRE
# GER
# GER
# GRE
# TPE
# VIE
# TPE
# IRI
# MAS
# BUL
# TPE
# MAD
# BAN
# BUL
# BUL
# GER
# BUL
# GRE
# RSA
# SAM
# PLE
# BUL
# IRI
# GRE
# GER
# IRI
# BAN
# GRE
# NED
# GRE
# TPE
# BUL
# RSA
# BAN
# TPE
# WAL
# BAN
# GRE
# BAN
# BUL
# PUR
# GRE
# BUL
# ALG
# TPE
# BUL
# IRI
# LAT
# GRE
# GER
# CHI
# CRO
# BUL
# BUL
# GER
# GRE
# SUI
# TPE
# CHI
# GER
# VIE
# TPE
# INA
# INA
# ESA
# INA
# GRE
# TPE
# BUL
# CRO
# CHI
# BUL
# BUL
# TPE
# GER
# PUR
# TPE
# CRO
# GER
# GRE
# BUL
# GRE
# CRO
# TPE
# CHI
# BUL
# CRO
# RSA
# CHI
# CHI
# GER
# GRE
# GER
# GRE
# GER
# PUR
# CHI
# TPE
# BUL
# ESA
# GRE
# BUL
# GRE
# TPE
# TPE
# CHI
# NED
# VIE
# TPE
# PUR
# BUL
# BUL
# INA
# TPE
# INA
# TPE
# GRE
# GRE
# PUR
# TPE
# ESA
# BUL
# TPE
# VIE
# BUL
# GRE
# CHI
# BUL
# BUL
# WAL
# INA
# GER
# VIE
# GRE
# LAT
# BUL
# GRE
# IRI
# IRI
# GER
# TPE
# TPE
# INA
# RSA
# BAN
# VIE
# BUL
# GRE
# GER
# IRI
# IRI
# TPE
# LAT
# SAM
# INA
# VIE
# BAN
# GRE
# INA
# GRE
# ESA
# TPE
# VIE
# MAS
# BUL
# INA
# BUL
# VIE
# TPE
# MAS
# NGR
# HON
# NEP
# MAS
# SRI
# BUL
# BUL
# MAS
# GRE
# TPE
# TPE
# INA
# GER
# NGR
# GER
# LAT
# VIE
# RSA
# MAS
# BUL
# GER
# INA
# IRI
# IRI
# NGR
# MAS
# HON
# MON
# GRE
# VIE
# BUL
# GRE
# GER
# LAT
# IRI
# LAT
# IRI
# INA
# RSA
# GRE
# GER
# TPE
# INA
# VIE
# GER
# GRE
# GRE
# NGR
# SAM
# BUL
# ESA
# BUL
# TPE
# TGA
# VIE
# INA
# VIE
# TPE
# BUL
# MYA
# TPE
# RSA
# NGR
# INA
# VIE
# TPE
# GRE
# GER
# MYA
# GRE
# NGR
# TPE
# TPE
# GRE
# SOL
# VIE
# MYA
# GRE
# VIE
# BUL
# NGR
# INA
# LAT
# NEP
# NED
# INA
# MYA
# VIE
# GRE
# TPE
# BUL
# INA
# BUL
# NGR
# MYA
# VIE
# GER
# BUL
# RSA
# INA
# MYA
# GER
# TPE
# LAT
# PLE
# INA
# TPE
# INA
# TPE
# IRI
# INA
# SRI
# WAL
# CRO
# PLE
# GER
# PLE
# MRI
# UAE
# IRI
# TPE
# LAT
# PLE
# SAM
# NGR
# GER
# NGR
# TPE
# TPE
# NGR
# TPE
# TPE
# TPE
# GER
# INA
# IRI
# GER
# IRI
# GRE
# TPE
# GUA
# TPE
# RSA
# LAT
# GER
# IRI
# IRI
# LAT
# GER
# LAT
# GRE
# TPE
# TPE
# INA
# INA
# ESA
# ESA
# FIJ
# KSA
# KSA
# VIE
# INA
# INA
# GRE
# RSA
# KSA
# INA
# TPE
# RSA
# IRI
# INA
# KSA
# IRI
# GER
# INA
# SUI
# RSA
# KSA
# KSA
# KOS
# GER
# GRE
# URU
# KSA
# MRI
# CRO
# IRI
# GRE
# GER
# GRE
# TPE
# RSA
# PUR
# KSA
# GER
# TPE
# MGL
# MGL
# TPE
# RSA
# GRE
# INA
# INA
# TPE
# GER
# TPE
# DEN
# GRE
# UAE
# PUR
# MGL
# INA
# GER
# UAE
# UAE
# TPE
# MGL
# GRE
# MGL
# PUR
# MGL
# INA
# VIE
# INA
# GER
# TPE
# PUR
# TPE
# GER
# PUR
# MGL
# IRI
# IRI
# GER
# TPE
# GUA
# CRO
# LAT
# CRC
# IRI
# IRI
# LAT
# GER
# TPE
# SAM
# CHI
# VIE
# TPE
# PHI
# ESA
# FIJ
# ESA
# TPE
# VIE
# INA
# INA
# INA
# MAS
# GRE
# ASA
# IRI
# MAS
# INA
# INA
# GER
# GUA
# GER
# NGR
# INA
# GRE
# TPE
# SUI
# IRI
# GER
# SUI
# CRO
# IRI
# IRI
# GRE
# GRE
# NGR
# PUR
# SAM
# NGR
# GER
# TPE
# SAM
# PUR
# INA
# ESA
# TPE
# NGR
# GER
# INA
# INA
# GRE
# DEN
# MAS
# PHI
# TPE
# GER
# GER
# NGR
# FIJ
# SOL
# MGL
# NGR
# VIE
# GRE
# MGL
# TPE
# TPE
# INA
# SEY
# GER
# SOL
# NGR
# SAM
# GER
# GER
# NGR
# IRI
# GUA
# IRI
# LAT
# IRI
# GRE
# CRO
# VIE
# VIE
# BUL
# BUL
# IRI
# IRI
# IRI
# GER
# SEY
# IRI
# GER
# BUL
# BUL
# GER
# VIE
# NED
# CRO
# GER
# GRE
# IRI
# MAS
# GUA
# VIE
# PUR
# MAS
# TPE
# SEY
# BUL
# MGL
# IRI
# GER
# TPE
# CRO
# GER
# IRI
# LAT
# IRI
# GER
# GER
# TPE
# ALG
# VIE
# VIE
# TPE
# KSA
# IRI
# INA
# MAS
# TPE
# BUL
# CHI
# KSA
# ALG
# INA
# INA
# BUL
# KSA
# KSA
# TPE
# ALG
# GRE
# MGL
# BUL
# INA
# IRI
# INA
# TPE
# GER
# MAS
# KSA
# TPE
# IRI
# KSA
# BUL
# INA
# GER
# GER
# VIE
# GRE
# ALG
# DEN
# IRI
# BUL
# GRE
# GER
# GRE
# IRI
# LBA
# KSA
# VIE
# CRO
# ALG
# INA
# BUL
# ALG
# GRE
# KSA
# VIE
# INA
# MRI
# GER
# INA
# PUR
# TPE
# BUL
# GER
# INA
# LAT
# MGL
# MGL
# TPE
# TPE
# GRE
# MRI
# GRE
# CRO
# UAE
# TPE
# GER
# CRO
# BUL
# MGL
# INA
# MGL
# NED
# TPE
# CHI
# GER
# GER
# CHI
# TPE
# GER
# GER
# IRI
# CRO
# LAT
# GER
# GER
# BUL
# IRI
# VIE
# PHI
# INA
# INA
# VIE
# TPE
# FIJ
# MGL
# CHI
# KSA
# INA
# INA
# VIE
# KSA
# TPE
# IRI
# SRI
# TPE
# MGL
# BUL
# KSA
# BUL
# ESA
# INA
# INA
# TPE
# GER
# GER
# KSA
# KSA
# MGL
# IRI
# SRI
# KOS
# GER
# GER
# INA
# VIE
# CHI
# DEN
# SRI
# MGL
# MGL
# IRI
# BUL
# IRI
# VIE
# INA
# CRO
# SUI
# IRI
# TPE
# ASA
# DEN
# NGR
# MRI
# GRE
# VIE
# TPE
# INA
# MRI
# GER
# PUR
# VIE
# TPE
# PHI
# LAT
# INA
# INA
# MGL
# NCA
# MGL
# DEN
# URU
# TPE
# TPE
# SOL
# DEN
# MGL
# TPE
# NGR
# INA
# RSA
# SEY
# NCA
# MGL
# ARU
# MGL
# GER
# INA
# FIJ
# DEN
# TPE
# CHI
# TPE
# MGL
# CRC
# MGL
# IRI
# IRI
# ALG
# GER
# IRI
# LAT
# BUL
# IRI
# TPE
# DEN
# VIE
# VIE
# KSA
# FIJ
# MAS
# TPE
# BUL
# VIE
# KSA
# VIE
# KSA
# GER
# KSA
# KSA
# GER
# GER
# GER
# DEN
# TPE
# VIE
# CHI
# IRI
# GER
# CRO
# KSA
# VIE
# IRI
# GER
# IRI
# IRI
# BUL
# TPE
# GER
# VIE
# VIE
# BUL
# PHI
# MRI
# DEN
# VIE
# VIE
# TPE
# TPE
# LAT
# TPE
# RSA
# BUL
# MGL
# VIE
# TPE
# VIE
# FIJ
# PHI
# TPE
# MGL
# CHI
# TPE
# TPE
# MGL
# IRI
# TPE
# ALG
# GER
# IRI
# IRI
# SAM
# SAM
# RSA
# IRI
# BUL
# LAT
# BUL
# GER
# TGA
# DEN
# SAM
# BUL
# VIE
# INA
# VIE
# PHI
# INA
# TPE
# GER
# CHI
# TPE
# INA
# GER
# BUL
# PHI
# KSA
# ALG
# BUL
# INA
# KSA
# IRI
# INA
# TPE
# GER
# DEN
# PUR
# RSA
# GER
# LAT
# GER
# BUL
# CHI
# TPE
# DEN
# RSA
# KOS
# UAE
# CRO
# BUL
# CHI
# IRI
# SAM
# PUR
# IRI
# IRI
# TPE
# LAT
# GER
# GRE
# PUR
# DEN
# PUR
# INA
# SAM
# TPE
# TGA
# VIE
# BUL
# INA
# VIE
# MRI
# TPE
# INA
# PUR
# NGR
# GRE
# PHI
# MGL
# PHI
# NGR
# INA
# RSA
# DEN
# URU
# DEN
# KOS
# TPE
# LAT
# VIE
# NGR
# INA
# GER
# DEN
# PUR
# SLO
# PUR
# GER
# MGL
# NGR
# RSA
# BAN
# RSA
# TPE
# TPE
# PHI
# GRE
# MGL
# SUI
# DEN
# GER
# NGR
# SUI
# TPE
# MGL
# VIN
# CHI
# PUR
# DEN
# ALG
# TPE
# IRI
# NED
# GUA
# IRI
# IRI
# IRI
# DEN
# RSA
# BOT
# IRI
# LAT
# TGA
# BUL
# KSA
# VIE
# PHI
# IRI
# INA
# SRI
# VIE
# INA
# VIE
# MAS
# TPE
# GER
# KSA
# TPE
# SRI
# MAD
# SRI
# INA
# GER
# GUA
# KSA
# MAD
# SAM
# PHI
# TPE
# TPE
# MAS
# BUL
# LBA
# MGL
# BUL
# GER
# INA
# INA
# PUR
# DEN
# SRI
# SRI
# KSA
# PHI
# MAS
# BUL
# GER
# LAT
# CHI
# TPE
# SRI
# PUR
# RSA
# IRI
# IRI
# LBA
# CRO
# CHI
# CRO
# URU
# DEN
# MAS
# IRI
# LAT
# GER
# TPE
# SAM
# ALG
# PUR
# PUR
# IRI
# INA
# SAM
# SAM
# TGA
# INA
# VIE
# VIE
# PHI
# MAD
# CHI
# BUL
# CRO
# BAN
# NCA
# INA
# TPE
# MRI
# PHI
# TPE
# PUR
# SRI
# PHI
# TPE
# DEN
# SRI
# DEN
# SOL
# IRI
# MGL
# CRO
# BUL
# TPE
# LAT
# VIE
# RSA
# DEN
# SOL
# PHI
# MAS
# SUI
# CRO
# BOT
# PHI
# TPE
# GER
# GER
# VIE
# RSA
# MGL
# DEN
# MAD
# BAN
# URU
# CRO
# PHI
# IRI
# DEN
# DEN
# IRI
# TPE
# SUI
# MAS
# MGL
# CHI
# UAE
# VIN
# CHI
# DEN
# MGL
# PUR
# IRI
# TPE
# URS
# GDR
# TCH
# TCH
# URS
# TCH
# URS
# GDR
# GDR
# TCH
# ALG
# ZIM
# BUL
# LBA
# SUI
# URS
# BUL
# GRE
# TCH
# URS
# MGL
# GRE
# POR
# LBA
# MGL
# URS
# GDR
# GRE
# ALG
# LBA
# NEP
# URS
# BUL
# TCH
# ALG
# NGR
# NEP
# BUL
# GDR
# BUL
# GDR
# TCH
# GRE
# BUL
# URS
# BUL
# YUG
# MGL
# NGR
# GDR
# LIB
# URS
# BUL
# TCH
# BUL
# GDR
# YUG
# DEN
# ROM
# BUL
# GDR
# TCH
# TCH
# GRE
# GUA
# URS
# MYA
# CHN)
# CHN)
# JPN)
# JPN)
# INA)
# KOR)
# PAN)
# TUR)
# ISR)
# IND)
# TPE)
# EGY)
# POR)
# COL)
# TPE)
# SRI)
# POR)
# ESP)
# IND)
# LIB)
# CHN)
# CHN)
# JPN)
# JPN)
# KOR)
# ESP)
# FIN)
# USA)
# GRE)
# IND)
# TPE)
# COL)
# EGY)
# NEP)
# GUA)
# TUN)
# ROU)
# TUR)
# INA)
# ALG)
# CHN)
# ROU)
# TPE)
# JPN)
# JPN)
# KOR)
# INA)
# FIN)
# ROU)
# EGY)
# PAN)
# GBR)
# COL)
# NGR)
# IND)
# ECU)
# NCA)
# ESP)
# ALG)
# CHN)
# KOR)
# CHN)
# ROU)
# FIN)
# GBR)
# JPN)
# JPN)
# AUS)
# CHN)
# NGR)
# ITA)
# AUT)
# ESP)
# USA)
# SWE)
# NEP)
# SOL)
# CAN)
# GUA)
# TUN)
# FRG)
# CAN)
# ROU)
# GBR)
# CHN)
# IRQ)
# AUS)
# KOR)
# CAN)
# FRA)
# GBR)
# GRE)
# GRE)
# COL)
# EGY)
# KOR)
# PUR)
# UGA)
# SWZ)
# TUR)
# POR)
# AUT)
# ROU)
# AUS)
# JPN)
# GBR)
# EGY)
# KOR)
# CAN)
# NZL)
# USA)
# NZL)
# SWE)
# GBR)
# EGY)
# PER)
# TUR)
# PAN)
# FIN)
# GRE)
# ITA)
# URS
# FRG
# FRG
# TCH
# GRE
# NGR
# TCH
# GRE
# BUL
# TPE
# INA
# PHI
# LIB
# NEP
# TPE
# URS
# INA
# ALG
# PHI
# TPE
# INA
# TPE
# BUL
# BUL
# GRE
# PUR
# INA
# GDR)
# URS)
# CHN)
# POL)
# TUR)
# CHN)
# HUN)
# GRE)
# JPN)
# CAN)
# FIN)
# NGR)
# USA)
# POR)
# PAN)
# KOR)
# BRA)
# SAM)
# PNG)
# LIB)
# UGA)
# GUM)
# TPE)
# SMR)
# FIN)
# KOR)
# JPN)
# ESP)
# BUL)
# EUN
# EUN
# GER
# BUL
# TCH
# GER
# LAT
# LBA
# NGR
# EUN
# EUN
# BUL
# GER
# TCH
# TCH
# IRI
# DEN
# SAM
# KUW
# GRE
# GER
# EUN
# BUL
# GER
# GRE
# TCH
# IRI
# BUL
# NCA
# SRI
# BUL
# INA
# INA
# TPE
# MGL
# NCA
# BUL
# BUL
# GRE
# SAM
# GER
# INA
# ALG
# HON
# MAD
# EUN
# BUL
# GER
# ALG
# IRI
# EUN
# GER
# LAT
# GER
# IRI
# INA
# GRE
# DEN
# GUA
# SOL
# TGA
# SUD
# MGL
# GRE
# BUL
# GER
# TCH
# IRI
# URU
# RSA
# PUR
# EUN
# EUN
# EUN
# BUL
# ASA
# LIB
# GER
# GER
# GRE
# LAT
# NEP
# GER
# LAT
# GER
# MRI
# GRE
# BUL
# BUL
# TPE
# INA
# LAT
# GUA
# MRI
# GRE
# BUL
# PUR
# POR
# KSA
# GRE
# GRE
# BUL
# BUL
# TPE
# ALG
# ALG
# ESA
# YUG
# SOL
# BUL
# ALG
# BUL
# GER
# GRE
# NGR
# BUL
# GRE
# GER
# GER
# SAM
# URU
# ARU
# GRE
# GER
# BUL
# TPE
# LAT
# TPE
# FIJ
# SEY
# GRE
# GER
# BUL
# ASA
# TGA
# GRE
# GER
# LAT
# CHI
# KUW
# IRI
# GER
# LAT
# ASA
# LAT
# IRI
# BUL
# TGA
# TPE
# TPE
# GUA
# NCA
# MRI
# IOA
# BUL
# CRO
# GRE
# IRI
# NGR
# BUL
# BUL
# BUL
# GRE
# GRE
# GER
# PUR
# IRI
# GRE
# GER
# GRE
# SAM
# IRI
# GRE
# IRI
# GER
# LAT
# NGR
# GER
# INA
# INA
# MYA
# BUL
# BUL
# TPE
# INA
# NGR
# MYA
# MYA
# SEY
# ALG
# NGR
# GRE
# FIJ
# BUL
# BUL
# GRE
# ESA
# PUR
# NGR
# TPE
# IRI
# LAT
# BUL
# GUA
# GER
# GER
# ASA
# IRI
# INA
# ALG
# MAS
# TPE
# TPE
# INA
# INA
# TPE
# BUL
# GRE
# CRO
# TPE
# KSA
# KSA
# IRI
# GRE
# IRI
# BUL
# GER
# LBA
# GER
# SAM
# GRE
# GRE
# SEY
# LBA
# BUL
# IRI
# GRE
# IRI
# ARU
# BUL
# GRE
# KSA
# KSA
# GRE
# FIJ
# BUL
# TPE
# NGR
# TPE
# INA
# MYA
# INA
# INA
# NGR
# BUL
# GRE
# MGL
# VIE
# ALG
# GRE
# BUL
# BUL
# GRE
# ESA
# MRI
# TPE
# GER
# LAT
# IRI
# GER
# TGA
# GRE
# IRI
# GUA
# VIE
# INA
# TPE
# TPE
# MAS
# INA
# TPE
# INA
# GER
# SRI
# NEP
# INA
# NGR
# RSA
# FIJ
# MON
# NGR
# SEY
# IRI
# GER
# GRE
# GRE
# MRI
# SAM
# NGR
# GRE
# ESA
# TPE
# NCA
# INA
# GER
# PUR
# PHI
# SOL
# TPE
# VIE
# MGL
# ALG
# CHI
# IRI
# IRI
# GER
# TPE
# GUA
# ARU
# GER
# IRI
# LAT
# GER
# CHI
# ALG
# VIE
# INA
# FIJ
# INA
# INA
# ESA
# INA
# INA
# NGR
# SAM
# IRI
# BUL
# IRI
# IRI
# GRE
# KSA
# HON
# RSA
# SAM
# GUA
# NGR
# PUR
# MAD
# TPE
# INA
# VIE
# GER
# TPE
# GER
# SOL
# PHI
# BUL
# FIJ
# NCA
# TPE
# CHI
# UAE
# GER
# ALG
# GER
# IRI
# TPE
# IRI
# LAT
# GER
# North Korea
# Vietnam
# Dominican Republic
# Chinese Taipei
# Vietnam
# Philippines
# South Korea
# Venezuela
# INA
# MAS
# KSA
# TPE
# INA
# GER
# INA
# IRI
# GRE
# CRO
# VIE
# IRI
# IRI
# HON
# ASA
# North Korea
# United States
# South Korea
# South Korea
# Venezuela
# Cook Islands
# Venezuela
# Dominican Republic
# United States
# Chinese Taipei
# Vietnam
# Chinese Taipei
# Philippines
# South Korea
# Chinese Taipei
# Dominican Republic
# Venezuela
# Marshall Islands
# United Arab Emirates
# North Korea
# Great Britain
# North Korea
# United States
# Moldova

# %%
df["Nationality"].head()
# Out:
# 0    CHN
# 1    FIN
# 2    TPE
# 3    FRA
# 4    HUN
# Name: Nationality, dtype: object

# %%
country_codes["Alpha-3 code"].head()
# Out:
# 0    AFG
# 1    ALA
# 2    ALB
# 3    DZA
# 4    ASM
# Name: Alpha-3 code, dtype: object

# %%
remaining = []
for country in df["Nationality"].values.tolist():
    if not country in country_codes["Alpha-3 code"].values.tolist():
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
code_list
# Out:
# []

# %%
df["Nationality"][::-1].head()
# Out:
# 10198        BRA
# 10197        MAR
# 10196        TUR
# 10195    Moldova
# 10194        WSM
# Name: Nationality, dtype: object

# %%
code_list
# Out:
# []

# %%
remaining
# Out:
# ['TPE',
#  'GRE',
#  'TPE',
#  'BUL',
#  'TPE',
#  'BUL',
#  'GRE',
#  'BUL',
#  'TPE',
#  'BUL',
#  'GRE',
#  'GRE',
#  'BUL',
#  'TPE',
#  'BUL',
#  'GRE',
#  'TPE',
#  'TPE',
#  'GRE',
#  'BUL',
#  'TPE',
#  'GRE',
#  'GRE',
#  'GRE',
#  'TPE',
#  'GER',
#  'GER',
#  'LAT',
#  'LAT',
#  'TPE',
#  'GER',
#  'LAT',
#  'TPE',
#  'BUL',
#  'TPE',
#  'BUL',
#  'BUL',
#  'TPE',
#  'TPE',
#  'BUL',
#  'MAS',
#  'MAS',
#  'BUL',
#  'DEN',
#  'NED',
#  'SUI',
#  'TPE',
#  'ALG',
#  'BUL',
#  'BUL',
#  'GER',
#  'TPE',
#  'URU',
#  'LAT',
#  'TPE',
#  'NED',
#  'GER',
#  'LAT',
#  'GER',
#  'CHI',
#  'TPE',
#  'TPE',
#  'TPE',
#  'MYA',
#  'NGR',
#  'GRE',
#  'TPE',
#  'INA',
#  'MYA',
#  'TPE',
#  'INA',
#  'BUL',
#  'TPE',
#  'MYA',
#  'GRE',
#  'BUL',
#  'MYA',
#  'NED',
#  'TPE',
#  'INA',
#  'MYA',
#  'TPE',
#  'TPE',
#  'GRE',
#  'MYA',
#  'TPE',
#  'MYA',
#  'GRE',
#  'GRE',
#  'TPE',
#  'MYA',
#  'NGR',
#  'MYA',
#  'GER',
#  'GRE',
#  'LAT',
#  'GRE',
#  'GER',
#  'TPE',
#  'ALG',
#  'NED',
#  'GER',
#  'LAT',
#  'GER',
#  'CRO',
#  'BUL',
#  'ALG',
#  'GRE',
#  'CRO',
#  'BUL',
#  'BUL',
#  'TPE',
#  'POR',
#  'IRE',
#  'BUL',
#  'GRE',
#  'BUL',
#  'GRE',
#  'ALG',
#  'LAT',
#  'NED',
#  'DEN',
#  'BUL',
#  'BUL',
#  'GRE',
#  'GER',
#  'GER',
#  'TPE',
#  'SUI',
#  'CRO',
#  'GRE',
#  'GER',
#  'BUL',
#  'CRO',
#  'CRO',
#  'LAT',
#  'LAT',
#  'GRE',
#  'GER',
#  'GRE',
#  'GER',
#  'LAT',
#  'DEN',
#  'TPE',
#  'CRO',
#  'NED',
#  'TPE',
#  'GER',
#  'DEN',
#  'TPE',
#  'TPE',
#  'BUL',
#  'BUL',
#  'GRE',
#  'TPE',
#  'BUL',
#  'GRE',
#  'NED',
#  'TPE',
#  'GER',
#  'TPE',
#  'BUL',
#  'GER',
#  'GRE',
#  'DEN',
#  'GRE',
#  'GRE',
#  'TPE',
#  'IRI',
#  'LAT',
#  'GER',
#  'LAT',
#  'PUR',
#  'ALG',
#  'NED',
#  'DEN',
#  'NED',
#  'GER',
#  'DEN',
#  'IRI',
#  'GER',
#  'LAT',
#  'CHI',
#  'TPE',
#  'DEN',
#  'NGR',
#  'NED',
#  'GER',
#  'TPE',
#  'BUL',
#  'TPE',
#  'GUA',
#  'ALG',
#  'LAT',
#  'ESA',
#  'RSA',
#  'NGR',
#  'GRE',
#  'BUL',
#  'CRO',
#  'KSA',
#  'IRI',
#  'GUA',
#  'GUA',
#  'BUL',
#  'BUL',
#  'GRE',
#  'GRE',
#  'IRI',
#  'INA',
#  'DEN',
#  'ALG',
#  'IRI',
#  'ALG',
#  'TPE',
#  'RSA',
#  'NED',
#  'GRE',
#  'BUL',
#  'BUL',
#  'GER',
#  'NGR',
#  'LAT',
#  'NED',
#  'GUA',
#  'TPE',
#  'POR',
#  'SAM',
#  'POR',
#  'SUI',
#  'IRI',
#  'NED',
#  'IRI',
#  'GRE',
#  'GER',
#  'GRE',
#  'BUL',
#  'GER',
#  'LAT',
#  'LAT',
#  'SAM',
#  'CRO',
#  'TPE',
#  'SUI',
#  'SUI',
#  'GUA',
#  'URU',
#  'DEN',
#  'DEN',
#  'NED',
#  'GRE',
#  'GRE',
#  'BUL',
#  'IRI',
#  'GER',
#  'LAT',
#  'TPE',
#  'DEN',
#  'DEN',
#  'SUI',
#  'SUI',
#  'LBA',
#  'POR',
#  'NGR',
#  'NGR',
#  'DEN',
#  'TPE',
#  'BUL',
#  'INA',
#  'MYA',
#  'INA',
#  'TPE',
#  'MYA',
#  'POR',
#  'NED',
#  'TPE',
#  'INA',
#  'INA',
#  'MYA',
#  'NGR',
#  'BUL',
#  'BUL',
#  'GRE',
#  'DEN',
#  'POR',
#  'POR',
#  'TPE',
#  'BUL',
#  'MYA',
#  'NGR',
#  'MGL',
#  'ESA',
#  'GRE',
#  'POR',
#  'DEN',
#  'DEN',
#  'NED',
#  'ALG',
#  'NED',
#  'TPE',
#  'GRE',
#  'NGR',
#  'BUL',
#  'GER',
#  'FIJ',
#  'NED',
#  'DEN',
#  'ALG',
#  'DEN',
#  'PUR',
#  'BUL',
#  'BUL',
#  'GRE',
#  'NGR',
#  'ESA',
#  'PUR',
#  'DEN',
#  'NED',
#  'TPE',
#  'GRE',
#  'NGR',
#  'TPE',
#  'MYA',
#  'GER',
#  'GRE',
#  'GER',
#  'GRE',
#  'MRI',
#  'GER',
#  'CHI',
#  'BUL',
#  'BUL',
#  'GER',
#  'GRE',
#  'GER',
#  'SUI',
#  'CRO',
#  'IRI',
#  'TPE',
#  'BUL',
#  'CRO',
#  'BUL',
#  'GRE',
#  'NGR',
#  'ALG',
#  'IRI',
#  'BUL',
#  'BUL',
#  'GRE',
#  'GRE',
#  'SUI',
#  'IRI',
#  'GER',
#  'BUL',
#  'IRI',
#  'BUL',
#  'GRE',
#  'GER',
#  'TPE',
#  'NGR',
#  'GRE',
#  'GRE',
#  'NGR',
#  'TPE',
#  'TPE',
#  'NGR',
#  'BUL',
#  'MGL',
#  'DEN',
#  'GRE',
#  'TPE',
#  'BUL',
#  'ALG',
#  'TPE',
#  'GRE',
#  'NED',
#  'TPE',
#  'NGR',
#  'GRE',
#  'GRE',
#  'IRI',
#  'BUL',
#  'GER',
#  'CHI',
#  'BUL',
#  'IRI',
#  'GER',
#  'GER',
#  'CRO',
#  'TPE',
#  'TPE',
#  'GRE',
#  'BUL',
#  'GRE',
#  'CRO',
#  'GRE',
#  'TPE',
#  'LAT',
#  'IRI',
#  'IRI',
#  'BUL',
#  'BUL',
#  'IRI',
#  'IRI',
#  'BUL',
#  'LAT',
#  'BUL',
#  'IRI',
#  'LAT',
#  'GRE',
#  'GRE',
#  'BUL',
#  'GER',
#  'GRE',
#  'NED',
#  'LAT',
#  'IRI',
#  'GRE',
#  'GER',
#  'GRE',
#  'BUL',
#  'TPE',
#  'BUL',
#  'TPE',
#  'TPE',
#  'GRE',
#  'BUL',
#  'TPE',
#  'ALG',
#  'DEN',
#  'GRE',
#  'BUL',
#  'BUL',
#  'ALG',
#  'GRE',
#  'LAT',
#  'IRI',
#  'BUL',
#  'LAT',
#  'BUL',
#  'ALG',
#  'GER',
#  'GER',
#  'GER',
#  'IRI',
#  'GER',
#  'SUI',
#  'BUL',
#  'TPE',
#  'INA',
#  'TPE',
#  'KSA',
#  'ALG',
#  'INA',
#  'GRE',
#  'ESA',
#  'INA',
#  'KSA',
#  'TPE',
#  'KSA',
#  'ESA',
#  'TPE',
#  'INA',
#  'CRO',
#  'INA',
#  'IRI',
#  'KSA',
#  'KSA',
#  'IRI',
#  'BUL',
#  'GER',
#  'GER',
#  'ALG',
#  'TPE',
#  'IRI',
#  'IRI',
#  'KSA',
#  'BUL',
#  'PUR',
#  'SUI',
#  'BUL',
#  'BUL',
#  'IRI',
#  'GER',
#  'KSA',
#  'NED',
#  'GER',
#  'KSA',
#  'PUR',
#  'GRE',
#  'BUL',
#  'GRE',
#  'NGR',
#  'BUL',
#  'INA',
#  'TPE',
#  'GRE',
#  'TPE',
#  'NGR',
#  'ESA',
#  'INA',
#  'NGR',
#  'INA',
#  'INA',
#  'INA',
#  'NGR',
#  'GRE',
#  'PUR',
#  'TPE',
#  'BUL',
#  'BUL',
#  'ALG',
#  'NGR',
#  'TPE',
#  'PUR',
#  'BUL',
#  'TPE',
#  'ESA',
#  'BUL',
#  'TPE',
#  'BUL',
#  'NGR',
#  'TPE',
#  'GER',
#  'NGR',
#  'IRI',
#  'LAT',
#  'GRE',
#  'GER',
#  'GER',
#  'GRE',
#  'TPE',
#  'VIE',
#  'TPE',
#  'IRI',
#  'MAS',
#  'BUL',
#  'TPE',
#  'MAD',
#  'BAN',
#  'BUL',
#  'BUL',
#  'GER',
#  'BUL',
#  'GRE',
#  'RSA',
#  'SAM',
#  'PLE',
#  'BUL',
#  'IRI',
#  'GRE',
#  'GER',
#  'IRI',
#  'BAN',
#  'GRE',
#  'NED',
#  'GRE',
#  'TPE',
#  'BUL',
#  'RSA',
#  'BAN',
#  'TPE',
#  'WAL',
#  'BAN',
#  'GRE',
#  'BAN',
#  'BUL',
#  'PUR',
#  'GRE',
#  'BUL',
#  'ALG',
#  'TPE',
#  'BUL',
#  'IRI',
#  'LAT',
#  'GRE',
#  'GER',
#  'CHI',
#  'CRO',
#  'BUL',
#  'BUL',
#  'GER',
#  'GRE',
#  'SUI',
#  'TPE',
#  'CHI',
#  'GER',
#  'VIE',
#  'TPE',
#  'INA',
#  'INA',
#  'ESA',
#  'INA',
#  'GRE',
#  'TPE',
#  'BUL',
#  'CRO',
#  'CHI',
#  'BUL',
#  'BUL',
#  'TPE',
#  'GER',
#  'PUR',
#  'TPE',
#  'CRO',
#  'GER',
#  'GRE',
#  'BUL',
#  'GRE',
#  'CRO',
#  'TPE',
#  'CHI',
#  'BUL',
#  'CRO',
#  'RSA',
#  'CHI',
#  'CHI',
#  'GER',
#  'GRE',
#  'GER',
#  'GRE',
#  'GER',
#  'PUR',
#  'CHI',
#  'TPE',
#  'BUL',
#  'ESA',
#  'GRE',
#  'BUL',
#  'GRE',
#  'TPE',
#  'TPE',
#  'CHI',
#  'NED',
#  'VIE',
#  'TPE',
#  'PUR',
#  'BUL',
#  'BUL',
#  'INA',
#  'TPE',
#  'INA',
#  'TPE',
#  'GRE',
#  'GRE',
#  'PUR',
#  'TPE',
#  'ESA',
#  'BUL',
#  'TPE',
#  'VIE',
#  'BUL',
#  'GRE',
#  'CHI',
#  'BUL',
#  'BUL',
#  'WAL',
#  'INA',
#  'GER',
#  'VIE',
#  'GRE',
#  'LAT',
#  'BUL',
#  'GRE',
#  'IRI',
#  'IRI',
#  'GER',
#  'TPE',
#  'TPE',
#  'INA',
#  'RSA',
#  'BAN',
#  'VIE',
#  'BUL',
#  'GRE',
#  'GER',
#  'IRI',
#  'IRI',
#  'TPE',
#  'LAT',
#  'SAM',
#  'INA',
#  'VIE',
#  'BAN',
#  'GRE',
#  'INA',
#  'GRE',
#  'ESA',
#  'TPE',
#  'VIE',
#  'MAS',
#  'BUL',
#  'INA',
#  'BUL',
#  'VIE',
#  'TPE',
#  'MAS',
#  'NGR',
#  'HON',
#  'NEP',
#  'MAS',
#  'SRI',
#  'BUL',
#  'BUL',
#  'MAS',
#  'GRE',
#  'TPE',
#  'TPE',
#  'INA',
#  'GER',
#  'NGR',
#  'GER',
#  'LAT',
#  'VIE',
#  'RSA',
#  'MAS',
#  'BUL',
#  'GER',
#  'INA',
#  'IRI',
#  'IRI',
#  'NGR',
#  'MAS',
#  'HON',
#  'MON',
#  'GRE',
#  'VIE',
#  'BUL',
#  'GRE',
#  'GER',
#  'LAT',
#  'IRI',
#  'LAT',
#  'IRI',
#  'INA',
#  'RSA',
#  'GRE',
#  'GER',
#  'TPE',
#  'INA',
#  'VIE',
#  'GER',
#  'GRE',
#  'GRE',
#  'NGR',
#  'SAM',
#  'BUL',
#  'ESA',
#  'BUL',
#  'TPE',
#  'TGA',
#  'VIE',
#  'INA',
#  'VIE',
#  'TPE',
#  'BUL',
#  'MYA',
#  'TPE',
#  'RSA',
#  'NGR',
#  'INA',
#  'VIE',
#  'TPE',
#  'GRE',
#  'GER',
#  'MYA',
#  'GRE',
#  'NGR',
#  'TPE',
#  'TPE',
#  'GRE',
#  'SOL',
#  'VIE',
#  'MYA',
#  'GRE',
#  'VIE',
#  'BUL',
#  'NGR',
#  'INA',
#  'LAT',
#  'NEP',
#  'NED',
#  'INA',
#  'MYA',
#  'VIE',
#  'GRE',
#  'TPE',
#  'BUL',
#  'INA',
#  'BUL',
#  'NGR',
#  'MYA',
#  'VIE',
#  'GER',
#  'BUL',
#  'RSA',
#  'INA',
#  'MYA',
#  'GER',
#  'TPE',
#  'LAT',
#  'PLE',
#  'INA',
#  'TPE',
#  'INA',
#  'TPE',
#  'IRI',
#  'INA',
#  'SRI',
#  'WAL',
#  'CRO',
#  'PLE',
#  'GER',
#  'PLE',
#  'MRI',
#  'UAE',
#  'IRI',
#  'TPE',
#  'LAT',
#  'PLE',
#  'SAM',
#  'NGR',
#  'GER',
#  'NGR',
#  'TPE',
#  'TPE',
#  'NGR',
#  'TPE',
#  'TPE',
#  'TPE',
#  'GER',
#  'INA',
#  'IRI',
#  'GER',
#  'IRI',
#  'GRE',
#  'TPE',
#  'GUA',
#  'TPE',
#  'RSA',
#  'LAT',
#  'GER',
#  'IRI',
#  'IRI',
#  'LAT',
#  'GER',
#  'LAT',
#  'GRE',
#  'TPE',
#  'TPE',
#  'INA',
#  'INA',
#  'ESA',
#  'ESA',
#  'FIJ',
#  'KSA',
#  'KSA',
#  'VIE',
#  'INA',
#  'INA',
#  'GRE',
#  'RSA',
#  'KSA',
#  'INA',
#  'TPE',
#  'RSA',
#  'IRI',
#  'INA',
#  'KSA',
#  'IRI',
#  'GER',
#  'INA',
#  'SUI',
#  'RSA',
#  'KSA',
#  'KSA',
#  'KOS',
#  'GER',
#  'GRE',
#  'URU',
#  'KSA',
#  'MRI',
#  'CRO',
#  'IRI',
#  'GRE',
#  'GER',
#  'GRE',
#  'TPE',
#  'RSA',
#  'PUR',
#  'KSA',
#  'GER',
#  'TPE',
#  'MGL',
#  'MGL',
#  'TPE',
#  'RSA',
#  'GRE',
#  'INA',
#  'INA',
#  'TPE',
#  'GER',
#  'TPE',
#  'DEN',
#  'GRE',
#  'UAE',
#  'PUR',
#  'MGL',
#  'INA',
#  'GER',
#  'UAE',
#  'UAE',
#  'TPE',
#  'MGL',
#  'GRE',
#  'MGL',
#  'PUR',
#  'MGL',
#  'INA',
#  'VIE',
#  'INA',
#  'GER',
#  'TPE',
#  'PUR',
#  'TPE',
#  'GER',
#  'PUR',
#  'MGL',
#  'IRI',
#  'IRI',
#  'GER',
#  'TPE',
#  'GUA',
#  'CRO',
#  'LAT',
#  'CRC',
#  'IRI',
#  'IRI',
#  'LAT',
#  'GER',
#  'TPE',
#  'SAM',
#  'CHI',
#  'VIE',
#  'TPE',
#  'PHI',
#  'ESA',
#  'FIJ',
#  'ESA',
#  'TPE',
#  'VIE',
#  'INA',
#  'INA',
#  'INA',
#  'MAS',
#  'GRE',
#  'ASA',
#  'IRI',
#  'MAS',
#  'INA',
#  'INA',
#  'GER',
#  'GUA',
#  'GER',
#  'NGR',
#  'INA',
#  'GRE',
#  'TPE',
#  'SUI',
#  'IRI',
#  'GER',
#  'SUI',
#  'CRO',
#  'IRI',
#  'IRI',
#  'GRE',
#  'GRE',
#  'NGR',
#  'PUR',
#  'SAM',
#  'NGR',
#  'GER',
#  'TPE',
#  'SAM',
#  'PUR',
#  'INA',
#  'ESA',
#  'TPE',
#  'NGR',
#  'GER',
#  'INA',
#  'INA',
#  'GRE',
#  'DEN',
#  'MAS',
#  'PHI',
#  'TPE',
#  'GER',
#  'GER',
#  'NGR',
#  ...]

# %%
"""Three attempts:
dataframe index code
dataframe values to list index equals code
append to list, set new column to dataframe."""

code_list = []

for country in df["Nationality"].values.tolist():
    if country in country_codes["Country"].values.tolist():
        index = country_codes["Country"].values.tolist().index(country)
        code = country_codes["Alpha-3 code"][index]
        df["Nationality"][index] = code
    elif country not in country_codes["Alpha-3 code"].values.tolist():
        code_list.append(country)

# %%
code_list
# Out:
# ['TPE',
#  'GRE',
#  'TPE',
#  'BUL',
#  'TPE',
#  'BUL',
#  'GRE',
#  'BUL',
#  'TPE',
#  'BUL',
#  'GRE',
#  'GRE',
#  'BUL',
#  'TPE',
#  'BUL',
#  'GRE',
#  'TPE',
#  'TPE',
#  'GRE',
#  'BUL',
#  'TPE',
#  'GRE',
#  'GRE',
#  'GRE',
#  'TPE',
#  'GER',
#  'GER',
#  'LAT',
#  'LAT',
#  'TPE',
#  'GER',
#  'LAT',
#  'TPE',
#  'BUL',
#  'TPE',
#  'BUL',
#  'BUL',
#  'TPE',
#  'TPE',
#  'BUL',
#  'MAS',
#  'MAS',
#  'BUL',
#  'DEN',
#  'NED',
#  'SUI',
#  'TPE',
#  'ALG',
#  'BUL',
#  'BUL',
#  'GER',
#  'TPE',
#  'URU',
#  'LAT',
#  'TPE',
#  'NED',
#  'GER',
#  'LAT',
#  'GER',
#  'CHI',
#  'TPE',
#  'TPE',
#  'TPE',
#  'MYA',
#  'NGR',
#  'GRE',
#  'TPE',
#  'INA',
#  'MYA',
#  'TPE',
#  'INA',
#  'BUL',
#  'TPE',
#  'MYA',
#  'GRE',
#  'BUL',
#  'MYA',
#  'NED',
#  'TPE',
#  'INA',
#  'MYA',
#  'TPE',
#  'TPE',
#  'GRE',
#  'MYA',
#  'TPE',
#  'MYA',
#  'GRE',
#  'GRE',
#  'TPE',
#  'MYA',
#  'NGR',
#  'MYA',
#  'GER',
#  'GRE',
#  'LAT',
#  'GRE',
#  'GER',
#  'TPE',
#  'ALG',
#  'NED',
#  'GER',
#  'LAT',
#  'GER',
#  'CRO',
#  'BUL',
#  'ALG',
#  'GRE',
#  'CRO',
#  'BUL',
#  'BUL',
#  'TPE',
#  'POR',
#  'IRE',
#  'BUL',
#  'GRE',
#  'BUL',
#  'GRE',
#  'ALG',
#  'LAT',
#  'NED',
#  'DEN',
#  'BUL',
#  'BUL',
#  'GRE',
#  'GER',
#  'GER',
#  'TPE',
#  'SUI',
#  'CRO',
#  'GRE',
#  'GER',
#  'BUL',
#  'CRO',
#  'CRO',
#  'LAT',
#  'LAT',
#  'GRE',
#  'GER',
#  'GRE',
#  'GER',
#  'LAT',
#  'DEN',
#  'TPE',
#  'CRO',
#  'NED',
#  'TPE',
#  'GER',
#  'DEN',
#  'TPE',
#  'TPE',
#  'BUL',
#  'BUL',
#  'GRE',
#  'TPE',
#  'BUL',
#  'GRE',
#  'NED',
#  'TPE',
#  'GER',
#  'TPE',
#  'BUL',
#  'GER',
#  'GRE',
#  'DEN',
#  'GRE',
#  'GRE',
#  'TPE',
#  'IRI',
#  'LAT',
#  'GER',
#  'LAT',
#  'PUR',
#  'ALG',
#  'NED',
#  'DEN',
#  'NED',
#  'GER',
#  'DEN',
#  'IRI',
#  'GER',
#  'LAT',
#  'CHI',
#  'TPE',
#  'DEN',
#  'NGR',
#  'NED',
#  'GER',
#  'TPE',
#  'BUL',
#  'TPE',
#  'GUA',
#  'ALG',
#  'LAT',
#  'ESA',
#  'RSA',
#  'NGR',
#  'GRE',
#  'BUL',
#  'CRO',
#  'KSA',
#  'IRI',
#  'GUA',
#  'GUA',
#  'BUL',
#  'BUL',
#  'GRE',
#  'GRE',
#  'IRI',
#  'INA',
#  'DEN',
#  'ALG',
#  'IRI',
#  'ALG',
#  'TPE',
#  'RSA',
#  'NED',
#  'GRE',
#  'BUL',
#  'BUL',
#  'GER',
#  'NGR',
#  'LAT',
#  'NED',
#  'GUA',
#  'TPE',
#  'POR',
#  'SAM',
#  'POR',
#  'SUI',
#  'IRI',
#  'NED',
#  'IRI',
#  'GRE',
#  'GER',
#  'GRE',
#  'BUL',
#  'GER',
#  'LAT',
#  'LAT',
#  'SAM',
#  'CRO',
#  'TPE',
#  'SUI',
#  'SUI',
#  'GUA',
#  'URU',
#  'DEN',
#  'DEN',
#  'NED',
#  'GRE',
#  'GRE',
#  'BUL',
#  'IRI',
#  'GER',
#  'LAT',
#  'TPE',
#  'DEN',
#  'DEN',
#  'SUI',
#  'SUI',
#  'LBA',
#  'POR',
#  'NGR',
#  'NGR',
#  'DEN',
#  'TPE',
#  'BUL',
#  'INA',
#  'MYA',
#  'INA',
#  'TPE',
#  'MYA',
#  'POR',
#  'NED',
#  'TPE',
#  'INA',
#  'INA',
#  'MYA',
#  'NGR',
#  'BUL',
#  'BUL',
#  'GRE',
#  'DEN',
#  'POR',
#  'POR',
#  'TPE',
#  'BUL',
#  'MYA',
#  'NGR',
#  'MGL',
#  'ESA',
#  'GRE',
#  'POR',
#  'DEN',
#  'DEN',
#  'NED',
#  'ALG',
#  'NED',
#  'TPE',
#  'GRE',
#  'NGR',
#  'BUL',
#  'GER',
#  'FIJ',
#  'NED',
#  'DEN',
#  'ALG',
#  'DEN',
#  'PUR',
#  'BUL',
#  'BUL',
#  'GRE',
#  'NGR',
#  'ESA',
#  'PUR',
#  'DEN',
#  'NED',
#  'TPE',
#  'GRE',
#  'NGR',
#  'TPE',
#  'MYA',
#  'GER',
#  'GRE',
#  'GER',
#  'GRE',
#  'MRI',
#  'GER',
#  'CHI',
#  'BUL',
#  'BUL',
#  'GER',
#  'GRE',
#  'GER',
#  'SUI',
#  'CRO',
#  'IRI',
#  'TPE',
#  'BUL',
#  'CRO',
#  'BUL',
#  'GRE',
#  'NGR',
#  'ALG',
#  'IRI',
#  'BUL',
#  'BUL',
#  'GRE',
#  'GRE',
#  'SUI',
#  'IRI',
#  'GER',
#  'BUL',
#  'IRI',
#  'BUL',
#  'GRE',
#  'GER',
#  'TPE',
#  'NGR',
#  'GRE',
#  'GRE',
#  'NGR',
#  'TPE',
#  'TPE',
#  'NGR',
#  'BUL',
#  'MGL',
#  'DEN',
#  'GRE',
#  'TPE',
#  'BUL',
#  'ALG',
#  'TPE',
#  'GRE',
#  'NED',
#  'TPE',
#  'NGR',
#  'GRE',
#  'GRE',
#  'IRI',
#  'BUL',
#  'GER',
#  'CHI',
#  'BUL',
#  'IRI',
#  'GER',
#  'GER',
#  'CRO',
#  'TPE',
#  'TPE',
#  'GRE',
#  'BUL',
#  'GRE',
#  'CRO',
#  'GRE',
#  'TPE',
#  'LAT',
#  'IRI',
#  'IRI',
#  'BUL',
#  'BUL',
#  'IRI',
#  'IRI',
#  'BUL',
#  'LAT',
#  'BUL',
#  'IRI',
#  'LAT',
#  'GRE',
#  'GRE',
#  'BUL',
#  'GER',
#  'GRE',
#  'NED',
#  'LAT',
#  'IRI',
#  'GRE',
#  'GER',
#  'GRE',
#  'BUL',
#  'TPE',
#  'BUL',
#  'TPE',
#  'TPE',
#  'GRE',
#  'BUL',
#  'TPE',
#  'ALG',
#  'DEN',
#  'GRE',
#  'BUL',
#  'BUL',
#  'ALG',
#  'GRE',
#  'LAT',
#  'IRI',
#  'BUL',
#  'LAT',
#  'BUL',
#  'ALG',
#  'GER',
#  'GER',
#  'GER',
#  'IRI',
#  'GER',
#  'SUI',
#  'BUL',
#  'TPE',
#  'INA',
#  'TPE',
#  'KSA',
#  'ALG',
#  'INA',
#  'GRE',
#  'ESA',
#  'INA',
#  'KSA',
#  'TPE',
#  'KSA',
#  'ESA',
#  'TPE',
#  'INA',
#  'CRO',
#  'INA',
#  'IRI',
#  'KSA',
#  'KSA',
#  'IRI',
#  'BUL',
#  'GER',
#  'GER',
#  'ALG',
#  'TPE',
#  'IRI',
#  'IRI',
#  'KSA',
#  'BUL',
#  'PUR',
#  'SUI',
#  'BUL',
#  'BUL',
#  'IRI',
#  'GER',
#  'KSA',
#  'NED',
#  'GER',
#  'KSA',
#  'PUR',
#  'GRE',
#  'BUL',
#  'GRE',
#  'NGR',
#  'BUL',
#  'INA',
#  'TPE',
#  'GRE',
#  'TPE',
#  'NGR',
#  'ESA',
#  'INA',
#  'NGR',
#  'INA',
#  'INA',
#  'INA',
#  'NGR',
#  'GRE',
#  'PUR',
#  'TPE',
#  'BUL',
#  'BUL',
#  'ALG',
#  'NGR',
#  'TPE',
#  'PUR',
#  'BUL',
#  'TPE',
#  'ESA',
#  'BUL',
#  'TPE',
#  'BUL',
#  'NGR',
#  'TPE',
#  'GER',
#  'NGR',
#  'IRI',
#  'LAT',
#  'GRE',
#  'GER',
#  'GER',
#  'GRE',
#  'TPE',
#  'VIE',
#  'TPE',
#  'IRI',
#  'MAS',
#  'BUL',
#  'TPE',
#  'MAD',
#  'BAN',
#  'BUL',
#  'BUL',
#  'GER',
#  'BUL',
#  'GRE',
#  'RSA',
#  'SAM',
#  'PLE',
#  'BUL',
#  'IRI',
#  'GRE',
#  'GER',
#  'IRI',
#  'BAN',
#  'GRE',
#  'NED',
#  'GRE',
#  'TPE',
#  'BUL',
#  'RSA',
#  'BAN',
#  'TPE',
#  'WAL',
#  'BAN',
#  'GRE',
#  'BAN',
#  'BUL',
#  'PUR',
#  'GRE',
#  'BUL',
#  'ALG',
#  'TPE',
#  'BUL',
#  'IRI',
#  'LAT',
#  'GRE',
#  'GER',
#  'CHI',
#  'CRO',
#  'BUL',
#  'BUL',
#  'GER',
#  'GRE',
#  'SUI',
#  'TPE',
#  'CHI',
#  'GER',
#  'VIE',
#  'TPE',
#  'INA',
#  'INA',
#  'ESA',
#  'INA',
#  'GRE',
#  'TPE',
#  'BUL',
#  'CRO',
#  'CHI',
#  'BUL',
#  'BUL',
#  'TPE',
#  'GER',
#  'PUR',
#  'TPE',
#  'CRO',
#  'GER',
#  'GRE',
#  'BUL',
#  'GRE',
#  'CRO',
#  'TPE',
#  'CHI',
#  'BUL',
#  'CRO',
#  'RSA',
#  'CHI',
#  'CHI',
#  'GER',
#  'GRE',
#  'GER',
#  'GRE',
#  'GER',
#  'PUR',
#  'CHI',
#  'TPE',
#  'BUL',
#  'ESA',
#  'GRE',
#  'BUL',
#  'GRE',
#  'TPE',
#  'TPE',
#  'CHI',
#  'NED',
#  'VIE',
#  'TPE',
#  'PUR',
#  'BUL',
#  'BUL',
#  'INA',
#  'TPE',
#  'INA',
#  'TPE',
#  'GRE',
#  'GRE',
#  'PUR',
#  'TPE',
#  'ESA',
#  'BUL',
#  'TPE',
#  'VIE',
#  'BUL',
#  'GRE',
#  'CHI',
#  'BUL',
#  'BUL',
#  'WAL',
#  'INA',
#  'GER',
#  'VIE',
#  'GRE',
#  'LAT',
#  'BUL',
#  'GRE',
#  'IRI',
#  'IRI',
#  'GER',
#  'TPE',
#  'TPE',
#  'INA',
#  'RSA',
#  'BAN',
#  'VIE',
#  'BUL',
#  'GRE',
#  'GER',
#  'IRI',
#  'IRI',
#  'TPE',
#  'LAT',
#  'SAM',
#  'INA',
#  'VIE',
#  'BAN',
#  'GRE',
#  'INA',
#  'GRE',
#  'ESA',
#  'TPE',
#  'VIE',
#  'MAS',
#  'BUL',
#  'INA',
#  'BUL',
#  'VIE',
#  'TPE',
#  'MAS',
#  'NGR',
#  'HON',
#  'NEP',
#  'MAS',
#  'SRI',
#  'BUL',
#  'BUL',
#  'MAS',
#  'GRE',
#  'TPE',
#  'TPE',
#  'INA',
#  'GER',
#  'NGR',
#  'GER',
#  'LAT',
#  'VIE',
#  'RSA',
#  'MAS',
#  'BUL',
#  'GER',
#  'INA',
#  'IRI',
#  'IRI',
#  'NGR',
#  'MAS',
#  'HON',
#  'MON',
#  'GRE',
#  'VIE',
#  'BUL',
#  'GRE',
#  'GER',
#  'LAT',
#  'IRI',
#  'LAT',
#  'IRI',
#  'INA',
#  'RSA',
#  'GRE',
#  'GER',
#  'TPE',
#  'INA',
#  'VIE',
#  'GER',
#  'GRE',
#  'GRE',
#  'NGR',
#  'SAM',
#  'BUL',
#  'ESA',
#  'BUL',
#  'TPE',
#  'TGA',
#  'VIE',
#  'INA',
#  'VIE',
#  'TPE',
#  'BUL',
#  'MYA',
#  'TPE',
#  'RSA',
#  'NGR',
#  'INA',
#  'VIE',
#  'TPE',
#  'GRE',
#  'GER',
#  'MYA',
#  'GRE',
#  'NGR',
#  'TPE',
#  'TPE',
#  'GRE',
#  'SOL',
#  'VIE',
#  'MYA',
#  'GRE',
#  'VIE',
#  'BUL',
#  'NGR',
#  'INA',
#  'LAT',
#  'NEP',
#  'NED',
#  'INA',
#  'MYA',
#  'VIE',
#  'GRE',
#  'TPE',
#  'BUL',
#  'INA',
#  'BUL',
#  'NGR',
#  'MYA',
#  'VIE',
#  'GER',
#  'BUL',
#  'RSA',
#  'INA',
#  'MYA',
#  'GER',
#  'TPE',
#  'LAT',
#  'PLE',
#  'INA',
#  'TPE',
#  'INA',
#  'TPE',
#  'IRI',
#  'INA',
#  'SRI',
#  'WAL',
#  'CRO',
#  'PLE',
#  'GER',
#  'PLE',
#  'MRI',
#  'UAE',
#  'IRI',
#  'TPE',
#  'LAT',
#  'PLE',
#  'SAM',
#  'NGR',
#  'GER',
#  'NGR',
#  'TPE',
#  'TPE',
#  'NGR',
#  'TPE',
#  'TPE',
#  'TPE',
#  'GER',
#  'INA',
#  'IRI',
#  'GER',
#  'IRI',
#  'GRE',
#  'TPE',
#  'GUA',
#  'TPE',
#  'RSA',
#  'LAT',
#  'GER',
#  'IRI',
#  'IRI',
#  'LAT',
#  'GER',
#  'LAT',
#  'GRE',
#  'TPE',
#  'TPE',
#  'INA',
#  'INA',
#  'ESA',
#  'ESA',
#  'FIJ',
#  'KSA',
#  'KSA',
#  'VIE',
#  'INA',
#  'INA',
#  'GRE',
#  'RSA',
#  'KSA',
#  'INA',
#  'TPE',
#  'RSA',
#  'IRI',
#  'INA',
#  'KSA',
#  'IRI',
#  'GER',
#  'INA',
#  'SUI',
#  'RSA',
#  'KSA',
#  'KSA',
#  'KOS',
#  'GER',
#  'GRE',
#  'URU',
#  'KSA',
#  'MRI',
#  'CRO',
#  'IRI',
#  'GRE',
#  'GER',
#  'GRE',
#  'TPE',
#  'RSA',
#  'PUR',
#  'KSA',
#  'GER',
#  'TPE',
#  'MGL',
#  'MGL',
#  'TPE',
#  'RSA',
#  'GRE',
#  'INA',
#  'INA',
#  'TPE',
#  'GER',
#  'TPE',
#  'DEN',
#  'GRE',
#  'UAE',
#  'PUR',
#  'MGL',
#  'INA',
#  'GER',
#  'UAE',
#  'UAE',
#  'TPE',
#  'MGL',
#  'GRE',
#  'MGL',
#  'PUR',
#  'MGL',
#  'INA',
#  'VIE',
#  'INA',
#  'GER',
#  'TPE',
#  'PUR',
#  'TPE',
#  'GER',
#  'PUR',
#  'MGL',
#  'IRI',
#  'IRI',
#  'GER',
#  'TPE',
#  'GUA',
#  'CRO',
#  'LAT',
#  'CRC',
#  'IRI',
#  'IRI',
#  'LAT',
#  'GER',
#  'TPE',
#  'SAM',
#  'CHI',
#  'VIE',
#  'TPE',
#  'PHI',
#  'ESA',
#  'FIJ',
#  'ESA',
#  'TPE',
#  'VIE',
#  'INA',
#  'INA',
#  'INA',
#  'MAS',
#  'GRE',
#  'ASA',
#  'IRI',
#  'MAS',
#  'INA',
#  'INA',
#  'GER',
#  'GUA',
#  'GER',
#  'NGR',
#  'INA',
#  'GRE',
#  'TPE',
#  'SUI',
#  'IRI',
#  'GER',
#  'SUI',
#  'CRO',
#  'IRI',
#  'IRI',
#  'GRE',
#  'GRE',
#  'NGR',
#  'PUR',
#  'SAM',
#  'NGR',
#  'GER',
#  'TPE',
#  'SAM',
#  'PUR',
#  'INA',
#  'ESA',
#  'TPE',
#  'NGR',
#  'GER',
#  'INA',
#  'INA',
#  'GRE',
#  'DEN',
#  'MAS',
#  'PHI',
#  'TPE',
#  'GER',
#  'GER',
#  'NGR',
#  ...]

# %%
for country in df["na"]

# %%
"""Three attempts:
dataframe index code
dataframe values to list index equals code
append to list, set new column to dataframe."""

code_list = []

for country in df["Nationality"].values.tolist():
    if country in country_codes["Country"].values.tolist():
        index = country_codes["Country"].values.tolist().index(country)
        code = country_codes["Alpha-3 code"][index]
        df["Nationality"][index] = code
#         code_list.append(code)
#         df["Nationality"][index] = code_list[index]
    else:
        index = df["Nationality"].values.tolist().index(country)
        code = df["Nationality"].values.tolist()[index]
#         code_list.append(code)
#         df["Nationality"][index] = code_list[index]

# %%
df["Nationality"][::-1].values.tolist()
# Out:
# ['BRA',
#  'MAR',
#  'TUR',
#  'Moldova',
#  'WSM',
#  'ARM',
#  'MEX',
#  'FRA',
#  'CHL',
#  'United States',
#  'UKR',
#  'COL',
#  'ESP',
#  'BLR',
#  'North Korea',
#  'BLR',
#  'ROU',
#  'POL',
#  'CMR',
#  'TKM',
#  'TUR',
#  'FJI',
#  'Great Britain',
#  'CAN',
#  'MNG',
#  'ECU',
#  'BLR',
#  'ARM',
#  'COL',
#  'EGY',
#  'KAZ',
#  'CHN',
#  'THA',
#  'TUR',
#  'MDG',
#  'ARG',
#  'FIN',
#  'JPN',
#  'CUB',
#  'EGY',
#  'ITA',
#  'MEX',
#  'COL',
#  'KAZ',
#  'North Korea',
#  'CHN',
#  'United Arab Emirates',
#  'SLB',
#  'AUS',
#  'UKR',
#  'SWE',
#  'Marshall Islands',
#  'DEU',
#  'Venezuela',
#  'MEX',
#  'COL',
#  'Dominican Republic',
#  'JPN',
#  'ECU',
#  'Chinese Taipei',
#  'THA',
#  'THA',
#  'CHN',
#  'URY',
#  'PER',
#  'NIC',
#  'PRI',
#  'ALB',
#  'IDN',
#  'JPN',
#  'BRA',
#  'LVA',
#  'South Korea',
#  'Philippines',
#  'Chinese Taipei',
#  'Vietnam',
#  'IND',
#  'KGZ',
#  'MUS',
#  'UKR',
#  'Chinese Taipei',
#  'United States',
#  'KAZ',
#  'Dominican Republic',
#  'JPN',
#  'IDN',
#  'THA',
#  'Venezuela',
#  'DZA',
#  'Cook Islands',
#  'NZL',
#  'GEO',
#  'TUN',
#  'UKR',
#  'NGA',
#  'ROU',
#  'Venezuela',
#  'South Korea',
#  'South Korea',
#  'EGY',
#  'United States',
#  'North Korea',
#  'CHN',
#  'ASA',
#  'KEN',
#  'CMR',
#  'HON',
#  'GBR',
#  'AUS',
#  'FRA',
#  'USA',
#  'KOR',
#  'UKR',
#  'BLR',
#  'IRI',
#  'UKR',
#  'EGY',
#  'THA',
#  'LTU',
#  'BLR',
#  'IRI',
#  'ROU',
#  'ARM',
#  'MLT',
#  'GHA',
#  'MAR',
#  'FIN',
#  'BRA',
#  'VIE',
#  'NZL',
#  'CRO',
#  'KOR',
#  'CAN',
#  'GRE',
#  'CUB',
#  'FRA',
#  'FRA',
#  'QAT',
#  'BLR',
#  'BLR',
#  'UKR',
#  'KAZ',
#  'CHN',
#  'IRI',
#  'ROU',
#  'ARM',
#  'INA',
#  'IND',
#  'GER',
#  'EGY',
#  'PRK',
#  'ESP',
#  'COL',
#  'MDA',
#  'THA',
#  'EGY',
#  'CHN',
#  'KAZ',
#  'KGZ',
#  'INA',
#  'TUN',
#  'PRK',
#  'TPE',
#  'KSA',
#  'COL',
#  'UZB',
#  'PRK',
#  'MAS',
#  'THA',
#  'ESP',
#  'INA',
#  'KOR',
#  'FRA',
#  'MDA',
#  'ALB',
#  'MEX',
#  'COL',
#  'TUR',
#  'CHN',
#  'LKA',
#  'CHN',
#  'HTI',
#  'Venezuela',
#  'SYC',
#  'JPN',
#  'CHL',
#  'SLV',
#  'South Korea',
#  'WSM',
#  'IDN',
#  'PNG',
#  'EGY',
#  'JPN',
#  'KAZ',
#  'IDN',
#  'COL',
#  'MNG',
#  'ESP',
#  'Philippines',
#  'Vietnam',
#  'NRU',
#  'BEL',
#  'FJI',
#  'Chinese Taipei',
#  'JPN',
#  'GTM',
#  'THA',
#  'Dominican Republic',
#  'ITA',
#  'COL',
#  'Vietnam',
#  'KAZ',
#  'THA',
#  'North Korea',
#  'CHN',
#  'BRA',
#  'GEO',
#  'POL',
#  'KIR',
#  'PER',
#  'EGY',
#  'AUT',
#  'GER',
#  'IRQ',
#  'LAT',
#  'POL',
#  'IRI',
#  'UZB',
#  'CHN',
#  'KAZ',
#  'ARM',
#  'UZB',
#  'TKM',
#  'EGY',
#  'TPE',
#  'IRI',
#  'UKR',
#  'SVK',
#  'ISR',
#  'GER',
#  'SYR',
#  'ECU',
#  'ALG',
#  'BLR',
#  'UZB',
#  'HUN',
#  'GER',
#  'CZE',
#  'EST',
#  'UZB',
#  'BRA',
#  'ARM',
#  'GEO',
#  'ARM',
#  'GEO',
#  'BLR',
#  'RUS',
#  'KAZ',
#  'RUS',
#  'UAE',
#  'SYR',
#  'KOR',
#  'CHI',
#  'BRA',
#  'POL',
#  'CMR',
#  'EGY',
#  'ESP',
#  'ARM',
#  'BLR',
#  'BLR',
#  'KOR',
#  'KEN',
#  'GBR',
#  'ECU',
#  'TUN',
#  'EGY',
#  'CAN',
#  'TPE',
#  'COL',
#  'KAZ',
#  'ROU',
#  'PRK',
#  'TUR',
#  'RUS',
#  'KAZ',
#  'PER',
#  'NCA',
#  'FIJ',
#  'AUS',
#  'MEX',
#  'BUL',
#  'CAN',
#  'AZE',
#  'UKR',
#  'COL',
#  'PHI',
#  'SOL',
#  'CAN',
#  'TUR',
#  'KOR',
#  'GER',
#  'GBR',
#  'ALB',
#  'COL',
#  'ECU',
#  'TPE',
#  'BLR',
#  'PRK',
#  'THA',
#  'THA',
#  'CHN',
#  'MDA',
#  'KAZ',
#  'TUR',
#  'CHN',
#  'DOM',
#  'SGP',
#  'PNG',
#  'POL',
#  'JPN',
#  'GER',
#  'VEN',
#  'HKG',
#  'VIE',
#  'POL',
#  'COL',
#  'UKR',
#  'INA',
#  'TPE',
#  'UZB',
#  'THA',
#  'MAD',
#  'PUR',
#  'FRA',
#  'DOM',
#  'VEN',
#  'IND',
#  'JPN',
#  'TUR',
#  'THA',
#  'PRK',
#  'JPN',
#  'CHN',
#  'ARM',
#  'NGR',
#  'GHA',
#  'COK',
#  'GUA',
#  'USA',
#  'JPN',
#  'ECU',
#  'USA',
#  'SAM',
#  'EGY',
#  'KOR',
#  'RUS',
#  'CHN',
#  'ARM',
#  'KAZ',
#  'AZE',
#  'RUS',
#  'MDA',
#  'RUS',
#  'KAZ',
#  'POL',
#  'RSA',
#  'FIN',
#  'HON',
#  'KIR',
#  'GBR',
#  'KSA',
#  'ALB',
#  'GRE',
#  'UKR',
#  'BLR',
#  'POL',
#  'KOR',
#  'IRI',
#  'GEO',
#  'RUS',
#  'BLR',
#  'ARM',
#  'FRA',
#  'ROU',
#  'IRI',
#  'CHN',
#  'TKM',
#  'TUR',
#  'PNG',
#  'NZL',
#  'IRQ',
#  'THA',
#  'UZB',
#  'USA',
#  'BLR',
#  'CUB',
#  'EGY',
#  'BUL',
#  'EGY',
#  'IRI',
#  'POL',
#  'KOR',
#  'SAM',
#  'GBR',
#  'KAZ',
#  'NGR',
#  'POL',
#  'ESP',
#  'EGY',
#  'THA',
#  'CUB',
#  'CHN',
#  'CHN',
#  'FRA',
#  'FRA',
#  'UZB',
#  'AZE',
#  'ALB',
#  'ARM',
#  'TUR',
#  'GBR',
#  'THA',
#  'IND',
#  'COL',
#  'TKM',
#  'INA',
#  'PRK',
#  'EGY',
#  'ALB',
#  'AZE',
#  'KOR',
#  'TUR',
#  'VEN',
#  'PRK',
#  'ROU',
#  'INA',
#  'CHN',
#  'KOR',
#  'PLW',
#  'UGA',
#  'TUV',
#  'ESA',
#  'FSM',
#  'EGY',
#  'TUR',
#  'INA',
#  'TKM',
#  'TUR',
#  'CHN',
#  'INA',
#  'COL',
#  'PRK',
#  'ROU',
#  'AZE',
#  'TUN',
#  'UZB',
#  'KGZ',
#  'CUB',
#  'ITA',
#  'FIJ',
#  'BEL',
#  'CUB',
#  'PRK',
#  'COL',
#  'COL',
#  'MEX',
#  'INA',
#  'VIE',
#  'CHN',
#  'PRK',
#  'POL',
#  'KOR',
#  'GEO',
#  'ALG',
#  'CHI',
#  'KAZ',
#  'SVK',
#  'UKR',
#  'GER',
#  'ECU',
#  'LAT',
#  'SYR',
#  'UZB',
#  'UZB',
#  'POL',
#  'IRI',
#  'UKR',
#  'BLR',
#  'GER',
#  'ARU',
#  'CMR',
#  'AUS',
#  'GUA',
#  'NRU',
#  'JPN',
#  'BRA',
#  'HUN',
#  'TPE',
#  'GER',
#  'CZE',
#  'UKR',
#  'GEO',
#  'KOR',
#  'RUS',
#  'IRI',
#  'IRI',
#  'ARM',
#  'BLR',
#  'RUS',
#  'CHN',
#  'CHI',
#  'BLR',
#  'UKR',
#  'CAN',
#  'COL',
#  'MEX',
#  'ESP',
#  'KAZ',
#  'UKR',
#  'CHN',
#  'PRK',
#  'VEN',
#  'JPN',
#  'BLR',
#  'COL',
#  'EGY',
#  'COL',
#  'RUS',
#  'KAZ',
#  'KAZ',
#  'ALG',
#  'RUS',
#  'BOL',
#  'TUN',
#  'GBR',
#  'USA',
#  'VEN',
#  'USA',
#  'POL',
#  'MGL',
#  'COL',
#  'MEX',
#  'NOR',
#  'KOR',
#  'VIE',
#  'CAN',
#  'TPE',
#  'PRK',
#  'RUS',
#  'SOL',
#  'PHI',
#  'POL',
#  'PUR',
#  'ROU',
#  'POL',
#  'ALB',
#  'ECU',
#  'THA',
#  'PRK',
#  'CHN',
#  'BLR',
#  'VEN',
#  'PNG',
#  'GER',
#  'USA',
#  'DOM',
#  'INA',
#  'KOR',
#  'THA',
#  'TUR',
#  'TUR',
#  'CHN',
#  'ITA',
#  'THA',
#  'NCA',
#  'CAN',
#  'POL',
#  'JPN',
#  'FRA',
#  'JPN',
#  'THA',
#  'KOR',
#  'TPE',
#  'KAZ',
#  'UKR',
#  'ESA',
#  'PER',
#  'GRE',
#  'AUS',
#  'UKR',
#  'USA',
#  'NGR',
#  'SAM',
#  'KOR',
#  'AZE',
#  'RUS',
#  'KAZ',
#  'ECU',
#  'POL',
#  'MRI',
#  'GRE',
#  'GRE',
#  'MDA',
#  'MDA',
#  'UKR',
#  'ESP',
#  'GER',
#  'RUS',
#  'IRI',
#  'CUB',
#  'GEO',
#  'POL',
#  'AZE',
#  'KAZ',
#  'BLR',
#  'ARM',
#  'VEN',
#  'GEO',
#  'BLR',
#  'TUR',
#  'SEY',
#  'KIR',
#  'CMR',
#  'NGR',
#  'SVK',
#  'KGZ',
#  'COL',
#  'USA',
#  'UZB',
#  'FRA',
#  'CUB',
#  'ARM',
#  'CHN',
#  'USA',
#  'TUR',
#  'VEN',
#  'HUN',
#  'MON',
#  'FIJ',
#  'RSA',
#  'NZL',
#  'MDA',
#  'ARG',
#  'ROU',
#  'VEN',
#  'UZB',
#  'NGR',
#  'FRA',
#  'ALB',
#  'EGY',
#  'INA',
#  'BLR',
#  'KAZ',
#  'POL',
#  'ARM',
#  'CUB',
#  'RUS',
#  'KOR',
#  'ARM',
#  'CHN',
#  'KOR',
#  'MDA',
#  'ARM',
#  'KOR',
#  'COL',
#  'ALB',
#  'ITA',
#  'ROU',
#  'CHN',
#  'TJK',
#  'TUV',
#  'NEP',
#  'NZL',
#  'CYP',
#  'ROU',
#  'BRA',
#  'CAN',
#  'SRI',
#  'COL',
#  'GER',
#  'VEN',
#  'INA',
#  'EGY',
#  'JPN',
#  'THA',
#  'AZE',
#  'PRK',
#  'AZE',
#  'CUB',
#  'FRA',
#  'CHN',
#  'AZE',
#  'TKM',
#  'COL',
#  'PRK',
#  'KOR',
#  'CAN',
#  'FSM',
#  'BLR',
#  'TPE',
#  'EGY',
#  'TKM',
#  'CUB',
#  'THA',
#  'ROU',
#  'INA',
#  'COL',
#  'CHN',
#  'BLR',
#  'PRK',
#  'TUN',
#  'TUR',
#  'MDA',
#  'ITA',
#  'BEL',
#  'COL',
#  'JPN',
#  'THA',
#  'JPN',
#  'MAS',
#  'TPE',
#  'CUB',
#  'PRK',
#  'TPE',
#  'INA',
#  'VIE',
#  'CHN',
#  'UKR',
#  'RUS',
#  'SVK',
#  'LTU',
#  'ITA',
#  'GUA',
#  'CZE',
#  'TUR',
#  'EGY',
#  'SYR',
#  'UKR',
#  'IRI',
#  'GRE',
#  'POL',
#  'KAZ',
#  'GEO',
#  'KAZ',
#  'POL',
#  'RUS',
#  'BLR',
#  'KOR',
#  'TGA',
#  'COK',
#  'FIN',
#  'NRU',
#  'AUS',
#  'GER',
#  'POL',
#  'IRI',
#  'UKR',
#  'UKR',
#  'LAT',
#  'RUS',
#  'GER',
#  'TPE',
#  'EGY',
#  'MRI',
#  'AUS',
#  'MEX',
#  'ESA',
#  'DOM',
#  'ARG',
#  'COL',
#  'KOR',
#  'KAZ',
#  'GRE',
#  'HUN',
#  'RUS',
#  'RUS',
#  'THA',
#  'KOR',
#  'TUR',
#  'UGA',
#  'COL',
#  'CMR',
#  'BUL',
#  'UKR',
#  'BUL',
#  'RUS',
#  'HUN',
#  'CHN',
#  'IND',
#  'GRE',
#  'ALG',
#  'VIE',
#  'KOR',
#  'TUN',
#  'BLR',
#  'BLR',
#  'UKR',
#  'MGL',
#  'GRE',
#  'BUL',
#  'CAN',
#  'NGR',
#  'GBR',
#  'INA',
#  'ECU',
#  'PRK',
#  'POL',
#  'TUR',
#  'THA',
#  'PRK',
#  'CHN',
#  'IND',
#  'FRA',
#  'PNG',
#  'BLR',
#  'ROU',
#  'COL',
#  'INA',
#  'THA',
#  'MYA',
#  'INA',
#  'EGY',
#  'ESP',
#  'TPE',
#  'USA',
#  'JPN',
#  'PRK',
#  'NGR',
#  'TPE',
#  'BUL',
#  'IND',
#  'THA',
#  'CHN',
#  'TUR',
#  'FIJ',
#  'NRU',
#  'PER',
#  'COL',
#  'GRE',
#  'UKR',
#  'USA',
#  'UKR',
#  'HUN',
#  'POL',
#  'KOR',
#  'CHN',
#  'KSA',
#  'MDA',
#  'KSA',
#  'GRE',
#  'BUL',
#  'AZE',
#  'ARU',
#  'UZB',
#  'ARG',
#  'IRI',
#  'AZE',
#  'GEO',
#  'POL',
#  'CUB',
#  'GRE',
#  'MDA',
#  'ESP',
#  'UKR',
#  'KAZ',
#  'TUR',
#  'VEN',
#  'IRI',
#  'RUS',
#  'RUS',
#  'BUL',
#  'COM',
#  'TUR',
#  'LBA',
#  'AUS',
#  'RUS',
#  'FRA',
#  'ROU',
#  'GUY',
#  'KIR',
#  'SEY',
#  'KGZ',
#  'USA',
#  'COL',
#  'KOR',
#  'ARM',
#  'BLR',
#  'CHN',
#  'GRE',
#  'GRE',
#  'BLR',
#  'GEO',
#  'RUS',
#  'ROU',
#  'CHN',
#  'POL',
#  'ARM',
#  'SAM',
#  'GER',
#  'USA',
#  'COL',
#  'EGY',
#  'LBA',
#  'SVK',
#  'GER',
#  'ALB',
#  'VEN',
#  'ROU',
#  'KOR',
#  'QAT',
#  'BUL',
#  'HUN',
#  'IRI',
#  'GRE',
#  'TUR',
#  'KAZ',
#  'TUR',
#  'TUN',
#  'THA',
#  'IRI',
#  'SVK',
#  'KSA',
#  'KSA',
#  'ECU',
#  'TPE',
#  'ROU',
#  'NRU',
#  'FRA',
#  'BLR',
#  'CMR',
#  'AZE',
#  'CRO',
#  'KOR',
#  'CHN',
#  'GRE',
#  'COL',
#  'PRK',
#  'BUL',
#  'GBR',
#  'MAR',
#  'ROU',
#  'ALB',
#  'AZE',
#  'JPN',
#  'FSM',
#  'TPE',
#  'INA',
#  'TKM',
#  'FRA',
#  'INA',
#  'ARM',
#  'VEN',
#  'CHN',
#  'CHN',
#  'FRA',
#  'TPE',
#  'TPE',
#  'MAS',
#  'ALG',
#  'JPN',
#  'EGY',
#  'IRQ',
#  'COL',
#  'INA',
#  'HUN',
#  'ROU',
#  'COL',
#  'BLR',
#  'TUR',
#  'CHN',
#  'TUR',
#  'HUN',
#  'UKR',
#  'HUN',
#  'POL',
#  'IRI',
#  'QAT',
#  'SVK',
#  'CAN',
#  'ASA',
#  'COK',
#  'CZE',
#  'CUB',
#  'GER',
#  'BLR',
#  'UZB',
#  'AUT',
#  'AZE',
#  'LTU',
#  'MDA',
#  'RUS',
#  'UKR',
#  'RUS',
#  'ARM',
#  'GER',
#  'NOR',
#  'NRU',
#  'GUA',
#  'JPN',
#  ...]

# %%
code_list = []

for country in df["Nationality"].values.tolist():
    if country in country_codes["Country"].values.tolist():
        index = country_codes["Country"].values.tolist().index(country)
        code = country_codes["Alpha-3 code"][index]
        code_list.append(code)
        df["Nationality"][index] = code_list[index]
    else:
        index = df["Nationality"].values.tolist().index(country)
        code = df["Nationality"].values.tolist()[index]
        code_list.append(code)
        df["Nationality"][index] = code_list[index]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-119-10a7cf5d7228> in <module>
#      11         code = df["Nationality"].values.tolist()[index]
#      12         code_list.append(code)
# ---> 13         df["Nationality"][index] = code_list[index]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#     936
#     937         # do the setitem
# --> 938         cacher_needs_updating = self._check_is_chained_assignment_possible()
#     939         setitem(key, value)
#     940         if cacher_needs_updating:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _check_is_chained_assignment_possible(self)
#    2625             if ref is not None and ref._is_mixed_type:
#    2626                 self._check_setitem_copy(stacklevel=4, t='referant',
# -> 2627                                          force=True)
#    2628             return True
#    2629         elif self._is_copy:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    2672             try:
#    2673                 gc.collect(2)
# -> 2674                 if not gc.get_referents(self._is_copy()):
#    2675                     self._is_copy = None
#    2676                     return
#
# KeyboardInterrupt:

# %%
df[::-1].head()

# %%
code_list[::-1]

# %%
wf.CheckFunctions.change_nation_code(df)
# Out:
#        Year Event Gender  Comp Rank                     Athlete Name  \
# 0      1996   iwf      W        1.0                           Wan Ni
# 1      1996   iwf      W        2.0                Karoliina Lundahl
# 2      1996   iwf      W        3.0                  Chen Hsiao-lien
# 3      1996   iwf      W        4.0                     Sylvie Iskin
# 4      1996   iwf      W        5.0                  Erika TakÃƒÂ¡cs
# 5      1996   iwf      W        6.0                 Stamatia Bontozi
# 6      1996   iwf      W        7.0                    Decia Stenzel
# 7      1996   iwf      W        1.0                        Guan Hong
# 8      1996   iwf      W        2.0                   Kunjarani Devi
# 9      1996   iwf      W        3.0                   Tsai Huey-woan
# 10     1996   iwf      W        4.0                   Kaori Niyanagi
# 11     1996   iwf      W        5.0                   Donka Mincheva
# 12     1996   iwf      W        6.0                 Lubov Averianova
# 13     1996   iwf      W        7.0                    Loreen Briner
# 14     1996   iwf      W        1.0                       Liu Xiuhua
# 15     1996   iwf      W        2.0                  Choi Myung-shik
# 16     1996   iwf      W        3.0                      Chu Nan-mei
# 17     1996   iwf      W        4.0                 Izabela Rifatova
# 18     1996   iwf      W        5.0                    Anna Stroubou
# 19     1996   iwf      W        6.0                  Noriko Hasegawa
# 20     1996   iwf      W        7.0                     Siyka Stoeva
# 21     1996   iwf      W        8.0                  Csilla FÃƒÂ¶ldi
# 22     1996   iwf      W        9.0                 ErzsÃƒÂ©bet Nagy
# 23     1996   iwf      W        0.0                     Amanda Inman
# 24     1996   iwf      W        1.0                    Zhang Xixiang
# 25     1996   iwf      W        2.0                    Kuo Ping-chun
# 26     1996   iwf      W        3.0                Karnam Malleswari
# 27     1996   iwf      W        4.0                     Neli Yankova
# 28     1996   iwf      W        5.0                  Maryse Turcotte
# 29     1996   iwf      W        6.0                    Alfia Galieva
# ...     ...   ...    ...        ...                              ...
# 10169  2016   oly      W        3.0                       Sara Ahmed
# 10170  2016   oly      W        4.0                   Leydi SolÃƒÂ­s
# 10171  2016   oly      W        5.0                   Nazik Avdalyan
# 10172  2016   oly      W        6.0                   Darya Pachabut
# 10173  2016   oly      W        7.0                    Neisi Dajomes
# 10174  2016   oly      W        8.0  MÃƒÂ¶nkhjantsangiin Ankhtsetseg
# 10175  2016   oly      W        9.0   Marie-ÃƒË†ve Beauchemin-Nadeau
# 10176  2016   oly      W       10.0                    Rebekah Tiler
# 10177  2016   oly      W       11.0                  Apolonia Vaivai
# 10178  2016   oly      W       12.0                  Duygu AynacÃ„Â±
# 10179  2016   oly      W       13.0                Gulnabat Kadyrova
# 10180  2016   oly      W       14.0              Arcangeline Fouodji
# 10181  2016   oly      W        0.0              Patrycja Piechowiak
# 10182  2016   oly      W        0.0            Florina Sorina Hulpan
# 10183  2016   oly      W        0.0            Anastasiya Mikhalenka
# 10184  2016   oly      W        1.0                     Rim Jong-sim
# 10185  2016   oly      W        2.0                    Darya Naumava
# 10186  2016   oly      W        3.0                Lidia ValentÃƒÂ­n
# 10187  2016   oly      W        4.0                 Ubaldina Valoyes
# 10188  2016   oly      W        5.0                      Iryna Dekha
# 10189  2016   oly      W        6.0                     Jenny Arthur
# 10190  2016   oly      W        7.0      MarÃƒÂ­a Fernanda ValdÃƒÂ©s
# 10191  2016   oly      W        8.0         GaÃƒÂ«lle Nayo-Ketchanke
# 10192  2016   oly      W        9.0                  Alejandra Garza
# 10193  2016   oly      W       10.0                   Sona Poghosyan
# 10194  2016   oly      W       11.0                     Mary Opeloge
# 10195  2016   oly      W       12.0             Natalia PriÃˆâ„¢cepa
# 10196  2016   oly      W       13.0                   Assiya Ã„Â°pek
# 10197  2016   oly      W       14.0                     Samira Ouass
# 10198  2016   oly      W        0.0               Jaqueline Ferreira
#
#          Nationality Group Body Weight (kg) Snatch 1 (kg) Snatch 2 (kg)  \
# 0                CHN     A             84.4         102.5        -107.5
# 1                FIN     A             83.1           100           105
# 2                TPE     A            100.4           -95         -97.5
# 3                FRA     A            96.85          -100           100
# 4                HUN     A               96          97.5          -100
# 5                GRE     A            108.9          82.5           -85
# 6                USA     A             85.6           -90            90
# 7                CHN     A            44.75          72.5         -77.5
# 8                IND     A            45.45         -67.5         -67.5
# 9                TPE     A             45.6          67.5            70
# 10               JPN     A             45.8          62.5          67.5
# 11               BUL     A             45.8            65         -67.5
# 12               RUS     A             45.8          62.5             0
# 13               USA     A            45.85            60            65
# 14               CHN     A             49.9         -77.5           -80
# 15               KOR     A            49.95            75          77.5
# 16               TPE     A            49.15            75          77.5
# 17               BUL     A            49.75          72.5          77.5
# 18               GRE     A            49.45            70          72.5
# 19               JPN     A               50          67.5           -70
# 20               BUL     A             49.6          67.5           -70
# 21               HUN     A            49.35            60            65
# 22               HUN     A            49.05          57.5           -60
# 23               AUS     A            49.05          57.5           -60
# 24               CHN     A               54          82.5          87.5
# 25               TPE     A             53.6            80            85
# 26               IND     A             53.9            80           -85
# 27               BUL     A            53.05            75           -80
# 28               CAN     A            53.85          67.5            70
# 29               RUS     A            53.95            65           -70
# ...              ...   ...              ...           ...           ...
# 10169          Egypt     A               68           107           110
# 10170       Colombia     A            68.61           106          -110
# 10171        Armenia     A            68.55           103          -107
# 10172        Belarus     A            66.88          -105           105
# 10173        Ecuador     B            68.83           100           104
# 10174       Mongolia     A            68.97          -106           106
# 10175         Canada     A            68.81           -98            98
# 10176  Great Britain     B            68.59            98          -101
# 10177           Fiji     B            68.88           -88            88
# 10178         Turkey     B            68.83            85            88
# 10179   Turkmenistan     B            68.73            85            90
# 10180       Cameroon     B            68.08            77            82
# 10181         Poland     B            68.32            98           101
# 10182        Romania     A            67.52          -100          -100
# 10183        Belarus     A            67.23          -103          -103
# 10184    North Korea     A            74.47           117          -121
# 10185        Belarus     A            74.63           107           112
# 10186          Spain     A               74           112          -116
# 10187       Colombia     A            74.28           106           109
# 10188        Ukraine     A            74.89           111           114
# 10189  United States     A            74.65          -103           103
# 10190          Chile     B            74.66          -107          -107
# 10191         France     A            73.61           102          -107
# 10192         Mexico     B            74.59           -98            98
# 10193        Armenia     B            72.52            92            97
# 10194          Samoa     B            74.56            97           100
# 10195        Moldova     B            73.72            93            97
# 10196         Turkey     B            69.77            80            83
# 10197        Morocco     B            73.68            70            75
# 10198         Brazil     A            74.89          -103          -103
#
#       Snatch 3 (kg) Max Snatch  Snatch Rank C/J 1 (kg) C/J 2 (kg) C/J 3 (kg)  \
# 0              -110      102.5            2        130        135      137.5
# 1             107.5      107.5            1        125     -127.5     -127.5
# 2              97.5       97.5            4        130     -137.5     -137.5
# 3             102.5      102.5            2      117.5     -122.5      122.5
# 4              -100       97.5            4        120       -125       -125
# 5              87.5       87.5            7        110        115     -117.5
# 6               -95         90            6        105       -110       -110
# 7              77.5       77.5            1         95     -105.5     -105.5
# 8              67.5       67.5            3       87.5         90      -97.5
# 9             -72.5         70            2         85       87.5        -90
# 10              -70       67.5            3         85        -90        -90
# 11             67.5       67.5            3        -80         80       82.5
# 12                0       62.5            7       82.5          0          0
# 13              -70         65            6       72.5      -77.5        -80
# 14               80         80            1        100      102.5        105
# 15               80         80            1         95       -100       -100
# 16              -80       77.5            3         95      -97.5      -97.5
# 17              -80       77.5            3      -92.5       92.5      -97.5
# 18              -75       72.5            5         85      -87.5       87.5
# 19               70         70            6        -85         85         90
# 20              -70       67.5            7        -85         85        -90
# 21            -67.5         65            8         80        -85        -85
# 22              -60       57.5            9         75         80      -82.5
# 23              -60       57.5            9      -72.5      -72.5      -72.5
# 24              -90       87.5            1        105       -110        110
# 25            -87.5         85            2      102.5     -107.5     -107.5
# 26               85         85            2     -102.5     -102.5      102.5
# 27              -80         75            5         95        100     -102.5
# 28            -72.5         70            6         90         95      -97.5
# 29              -70         65            9         90         95      -97.5
# ...             ...        ...          ...        ...        ...        ...
# 10169           112        112            3        135        140        143
# 10170           110        110            4        140        143       -146
# 10171           107        107            5        130        133        135
# 10172          -108        105            8        126        132       -137
# 10173           107        107            5        130       -135       -135
# 10174          -108        106            7        131       -135       -135
# 10175          -103         98           12        130       -135       -136
# 10176           101        101            9        122       -126        126
# 10177           -92         88           15        108        113       -117
# 10178            90         90           13        105       -110        110
# 10179           -94         90           13       -100       -105        105
# 10180           -86         82           16        100        105       -110
# 10181          -103        101            9          0          0          0
# 10182           100        100           11          0          0          0
# 10183          -103       -103           17          0          0          0
# 10184           121        121            1        145        153       -162
# 10185           116        116            2        136        139        142
# 10186           116        116            2        135        138        141
# 10187           111        111            5        131        136       -138
# 10188          -116        114            4        133       -138       -141
# 10189           107        107            6        130        135       -141
# 10190           107        107            6        135       -142       -142
# 10191          -107        102            8        132        135       -140
# 10192          -101         98           10       -125        125        126
# 10193          -100         97           11        115        122        126
# 10194          -102        100            9        115        117        118
# 10195          -100         97           11        110        116       -123
# 10196           -85         83           13         95        100        103
# 10197           -80         75           14         90        -96         97
# 10198          -103       -103           15          0          0          0
#
#       Max C/J  C/J Rank  Total
# 0       137.5         1    240
# 1         125         3  232.5
# 2         130         2  227.5
# 3       122.5         4    225
# 4         120         5  217.5
# 5         115         6  202.5
# 6         105         7    195
# 7          95         1  172.5
# 8          90         2  157.5
# 9        87.5         3  157.5
# 10         85         4  152.5
# 11       82.5         5    150
# 12       82.5         5    145
# 13       72.5         7  137.5
# 14        105         1    185
# 15         95         2    175
# 16         95         2  172.5
# 17       92.5         4    170
# 18       87.5         6    160
# 19         90         5    160
# 20         85         7  152.5
# 21         80         8    145
# 22         80         8  137.5
# 23      -72.5        10      0
# 24        110         1  197.5
# 25      102.5         2  187.5
# 26      102.5         2  187.5
# 27        100         4    175
# 28         95         5    165
# 29         95         5    160
# ...       ...       ...    ...
# 10169     143         3    255
# 10170     143         3    253
# 10171     135         5    242
# 10172     132         6    237
# 10173     130         8    237
# 10174     131         7    237
# 10175     130         8    228
# 10176     126        10    227
# 10177     113        11    201
# 10178     110        12    200
# 10179     105        13    195
# 10180     105        13    187
# 10181       0        15      0
# 10182       0        15      0
# 10183       0        15      0
# 10184     153         1    274
# 10185     142         2    258
# 10186     141         3    257
# 10187     136         4    247
# 10188     133         8    247
# 10189     135         5    242
# 10190     135         5    242
# 10191     135         5    237
# 10192     126         9    224
# 10193     126         9    223
# 10194     118        11    218
# 10195     116        12    213
# 10196     103        13    186
# 10197      97        14    172
# 10198       0        15      0
#
# [10199 rows x 19 columns]

# %%
sns.distplot(df["Max Snatch"])

# %%
sns.distplot(df["Max C/J"])

# %%
sns.distplot(df["Total"])

# %%
sns.distplot(df["Body Weight (kg)"])

# %%
sns.lmplot(x="Year", y="Total", data=df, hue="Gender")

# %%
sns.lmplot(x="Year", y="Max Snatch", data=df, hue="Gender")

# %%
sns.lmplot(x="Year", y="Max C/J", data=df, hue="Gender")

# %%
sns.lmplot(x="Year", y="Body Weight (kg)", data=df, hue="Gender")

# %%
# This changes the "%Y-%m-%d %H:%M:%S" string format in the list to datetime format "%Y-%m-%d %H:%M:%S" 
# to be able to use seaborn graphs below.
for i in range(len(workout_data_list)):
    try:
        temp = datetime.strptime(workout_data_list[i][4], "%Y-%m-%d %H:%M:%S")
        temp.strftime("%Y-%m-%d %H:%M:%S")
        workout_data_list[i][4] = temp
    except:
        pass

# %%
workout_data = pd.DataFrame(workout_data_list)
workout_data.head()

# %%
workout_data.columns = "exercise, sets, reps, weight_lbs, datetime, duration_minutes".split(", ")
workout_data.head()

# %%
# A dataframe for total count of workouts for each exercise
workout_count = workout_data[["exercise", "datetime"]]
workout_count.head()

# %%
# Plot for total count of workouts for each exercise
plt.figure(figsize = (12,9))
sns.set_context("paper", font_scale = 2)
graph = sns.swarmplot(
    x="exercise", 
    y="datetime", 
    data=workout_count, 
    palette=colors, 
    order=exercise_names
    )
graph.set_xticklabels(graph.get_xticklabels(), rotation = 30)
graph.yaxis.set_major_locator(mdates.WeekdayLocator(interval=5))
graph.yaxis.set_major_formatter(mdates.DateFormatter("%b %d, %y"))
graph.set(
    title="Workout Count per Exercise", 
    xlabel="Exercise", 
    ylabel="Date"
    )
plt.savefig("Workout Count per Exercise.png")

# %%
# A dataframe for max weight by each exercise. 
exercise_max = workout_data[["exercise", "weight_lbs"]].groupby("exercise").max()
exercise_max["exercise"] = exercise_max.index
exercise_max

# %%
# Plot of max weight for each exercise
plt.figure(figsize = (12,9))
sns.set_context("paper", font_scale = 2)
graph = sns.barplot(
    x="exercise", 
    y="weight_lbs", 
    data=exercise_max, 
    order=exercise_names
    )
graph.set_xticklabels(graph.get_xticklabels(), rotation = 30)
graph.set(
    title="Max Lifts per Exercise", 
    xlabel="Exercise", 
    ylabel="Weight (lbs)", 
    yticks=np.arange(0, 300, 25)
    )
plt.savefig("Max Lifts per Exercise.png")

# %%
# A dataframe for total intensity(total weight lifted) for each exercise
total_intensity = workout_data[["exercise", "weight_lbs"]].groupby("exercise").sum()
total_intensity["exercise"] = total_intensity.index
total_intensity

# %%
# Plot of total intensity for each exercise
plt.figure(figsize = (12,9))
sns.set_context("paper", font_scale = 2)
graph = sns.barplot(
    x="exercise", 
    y="weight_lbs", 
    data=total_intensity, 
    order=exercise_names
    )
graph.set_xticklabels(graph.get_xticklabels(), rotation=30)
graph.set(
    title="Total Intensity", 
    xlabel="Exercise", 
    ylabel="Total Weight Lifted (lbs)", 
    yticks=np.arange(0, 8000, 500)
    )
plt.savefig("Total Intensity.png")

# %%
# A dataframe for total volume for each exercise
total_reps = workout_data["sets"]*workout_data["reps"]
workout_data["total volume"] = total_reps
total_volume = workout_data[["exercise", "total volume"]].groupby("exercise").sum()
total_volume["exercise"] = total_volume.index
total_volume

# %%
# Plot for total volume for each exercise
plt.figure(figsize = (12,9))
sns.set_context("paper", font_scale = 2)
graph = sns.barplot(
    x="exercise", 
    y="total volume", 
    data=total_volume, 
    order=exercise_names
    )
graph.set_xticklabels(graph.get_xticklabels(), rotation = 30)
graph.set(
    title="Total Volume per Exercise", 
    xlabel="Exercise", 
    ylabel="Total Reps", 
    yticks=np.arange(0, 1200, 100)
    )
plt.savefig("Total Volume.png")

# %%
squats_intensity = workout_data[
    ["exercise", "datetime", "weight_lbs"]
    ].loc[
    (workout_data["exercise"] == "BackSquat") | 
    (workout_data["exercise"] == "OverheadSquat") | 
    (workout_data["exercise"] == "FrontSquat")
    ]
squats_intensity.head()

# %%
squats_volume = workout_data[
    ["exercise", "datetime", "total volume"]
    ].loc[
    (workout_data["exercise"] == "BackSquat") | 
    (workout_data["exercise"] == "OverheadSquat") | 
    (workout_data["exercise"] == "FrontSquat")
    ]
squats_volume.head()

# %%
presses_intensity = workout_data[
    ["exercise", "datetime", "weight_lbs"]
    ].loc[(workout_data["exercise"] == "BenchPress") | 
    (workout_data["exercise"] == "ShoulderPress")]
presses_intensity.head()

# %%
presses_volume = workout_data[
    ["exercise", "datetime", "total volume"]
    ].loc[(workout_data["exercise"] == "BenchPress") | 
    (workout_data["exercise"] == "ShoulderPress")
    ]
presses_volume.head()

# %%
oly_lifts_intensity = workout_data[
    ["exercise", "datetime", "weight_lbs"]
    ].loc[
    (workout_data["exercise"] == "Clean&Jerk") | 
    (workout_data["exercise"] == "Snatch")
    ]
oly_lifts_intensity.head()

# %%
oly_lifts_volume = workout_data[
    ["exercise", "datetime", "total volume"]
    ].loc[(workout_data["exercise"] == "Clean&Jerk") | 
    (workout_data["exercise"] == "Snatch")
    ]
oly_lifts_volume.head()

# %%
# Plot comparison for intensity for squats.
plt.figure(figsize = (16,9))

sns.set_context("paper", font_scale = 2)
graph = sns.lineplot(
    x="datetime", 
    y="weight_lbs", 
    data=squats_intensity, 
    palette=colors[1:4], 
    hue="exercise", 
    linewidth=3
    )
graph.set_xticklabels(squats_intensity["datetime"].values, rotation = 30)
graph.xaxis.set_major_locator(mdates.WeekdayLocator(interval=5))
graph.xaxis.set_major_formatter(mdates.DateFormatter("%m/%d/%y"))
graph.set(
    title="Squats Intensity vs. Time", 
    xlabel="Time", 
    ylabel="Weight (lbs)", 
    yticks=np.arange(0, 250, 25)
    )
plt.legend(
    title="Exercise", 
    loc="upper right", 
    labels=squats_intensity["exercise"].unique()
    )
plt.savefig("Squats Intensity.png")

# %%
# Plot comparison for intensity for squats.
plt.figure(figsize = (16,9))

sns.set_context("paper", font_scale = 2)
graph = sns.lineplot(
    x="datetime", 
    y="total volume", 
    data=squats_volume, 
    palette=colors[1:4], 
    hue="exercise", 
    linewidth=3
    )
graph.set_xticklabels(squats_volume["datetime"].values, rotation = 30)
graph.xaxis.set_major_locator(mdates.WeekdayLocator(interval=5))
graph.xaxis.set_major_formatter(mdates.DateFormatter("%m/%d/%y"))
graph.set(
    title="Squats Volume vs. Time", 
    xlabel="Time", 
    ylabel="Total Reps per Session", 
    yticks=np.arange(0, 55, 5)
    )
plt.legend(
    title="Exercise", 
    loc="upper left", 
    labels=squats_volume["exercise"].unique()
    )
plt.savefig("Squats Volume.png")

# %%
# Plot comparison for intensity for squats.
plt.figure(figsize = (16,9))

sns.set_context("paper", font_scale = 2)
graph = sns.lineplot(
    x="datetime", 
    y="weight_lbs", 
    data=presses_intensity, 
    palette=colors[4:6], 
    hue="exercise", 
    linewidth=3
    )
graph.set_xticklabels(presses_intensity["datetime"].values, rotation = 30)
graph.xaxis.set_major_locator(mdates.WeekdayLocator(interval=5))
graph.xaxis.set_major_formatter(mdates.DateFormatter("%m/%d/%y"))
graph.set(
    title="Presses Intensity vs. Time", 
    xlabel="Time", 
    ylabel="Weight (lbs)", 
    yticks=np.arange(0, 200, 25)
    )
plt.legend(
    title="Exercise", 
    loc="upper right", 
    labels=presses_intensity["exercise"].unique()
    )
plt.savefig("Presses Intensity.png")

# %%
# Plot comparison for intensity for squats.
plt.figure(figsize = (16,9))

sns.set_context("paper", font_scale = 2)
graph = sns.lineplot(
    x="datetime", 
    y="total volume", 
    data=presses_volume, 
    palette=colors[4:6], 
    hue="exercise", 
    linewidth=3
    )
graph.set_xticklabels(presses_volume["datetime"].values, rotation = 30)
graph.xaxis.set_major_locator(mdates.WeekdayLocator(interval=5))
graph.xaxis.set_major_formatter(mdates.DateFormatter("%m/%d/%y"))
graph.set(
    title="Presses Volume vs. Time", 
    xlabel="Time", 
    ylabel="Total Reps per Session", 
    yticks=np.arange(0, 55, 5)
    )
plt.legend(
    title="Exercise", 
    loc="upper left", 
    labels=presses_volume["exercise"].unique()
    )
plt.savefig("Presses Volume.png")

# %%
# Plot comparison for intensity for squats.
plt.figure(figsize = (16,9))

sns.set_context("paper", font_scale = 2)
graph = sns.lineplot(
    x="datetime", 
    y="weight_lbs", 
    data=oly_lifts_intensity, 
    palette=colors[7:9], 
    hue="exercise", 
    linewidth=3
    )
graph.set_xticklabels(oly_lifts_intensity["datetime"].values, rotation = 30)
graph.xaxis.set_major_locator(mdates.WeekdayLocator(interval=5))
graph.xaxis.set_major_formatter(mdates.DateFormatter("%m/%d/%y"))
graph.set(
    title="Olympic Lifts Intensity vs. Time", 
    xlabel="Time", 
    ylabel="Weight (lbs)",
    yticks=np.arange(0, 150, 25)
    )
plt.legend(
    title="Exercise", 
    loc="upper right", 
    labels=oly_lifts_intensity["exercise"].unique()
    )
plt.savefig("Olympic Lifts Intensity.png")

# %%
# Plot comparison for intensity for squats.
plt.figure(figsize = (16,9))

sns.set_context("paper", font_scale = 2)
graph = sns.lineplot(
    x="datetime", 
    y="total volume", 
    data=oly_lifts_volume, 
    palette=colors[7:9], 
    hue="exercise", 
    linewidth=3
    )
graph.set_xticklabels(oly_lifts_volume["datetime"].values, rotation = 30)
graph.xaxis.set_major_locator(mdates.WeekdayLocator(interval=5))
graph.xaxis.set_major_formatter(mdates.DateFormatter("%m/%d/%y"))
graph.set(
    title="Olympic Lifts Volume vs. Time", 
    xlabel="Time", 
    ylabel="Total Reps per Session",
    yticks=np.arange(0, 30, 3)
    )
plt.legend(
    title="Exercise", 
    loc="upper right", 
    labels=oly_lifts_volume["exercise"].unique()
    )
plt.savefig("Olympic Lifts Volume.png")

# %%
""" Analytics Below """

# %%
# Shoulder Press Volume to Deadlift Volme Percent Ratio
dl = total_volume.loc["Deadlift"][0]
sp = total_volume.loc["ShoulderPress"][0]

round(sp/dl*100, 2)

# %%
# Deadlift Max to Shoulder Press Max Percent Ratio
dl = exercise_max.loc["Deadlift"][0]
sp = exercise_max.loc["ShoulderPress"][0]

round(dl/sp*100, 2)

# %%
# Squats Total Volume to Presses Total Volume Percent Ratio
sq = squats_volume["total volume"].sum()
pr = presses_volume["total volume"].sum()

round(sq/pr*100, 2)

# %%
# Squts Total Intensity to Presses Total Intensity Percent Ratio
sq = squats_intensity["weight_lbs"].sum()
pr = presses_intensity["weight_lbs"].sum()

round(sq/pr*100, 2)

# %%
# Snatch Total Volume to Clean&Jerk Total Volume Percent Ratio
cj = total_volume.loc["Clean&Jerk"][0]
sn = total_volume.loc["Snatch"][0]

round(sn/cj*100, 2)

# %%
# Snatch Total Intensity to Clean&Jerk Total Intensity Percent Ratio
cj = total_intensity.loc["Clean&Jerk"][0]
sn = total_intensity.loc["Snatch"][0]

round(sn/cj*100, 2)

# %%
# Front Squat Max to Back Squat Max Percent Ratio
fs = exercise_max.loc["FrontSquat"][0]
bs = exercise_max.loc["BackSquat"][0]

round(fs/bs*100, 2)

# %%
# Average duration of workouts out of 111 workouts with non-null data in duration_minutes
len(workout_data["duration_minutes"].loc[workout_data["duration_minutes"] != -1]) # No. workouts with non-null duration

avg_duration = workout_data["duration_minutes"].loc[workout_data["duration_minutes"] != -1].mean()
round(avg_duration, 2)

# %%
# Average number of sets in workouts
avg_sets = workout_data["sets"].mean()
round(avg_sets, 2)

# %%
# Average number of reps in workouts
avg_reps = workout_data["reps"].mean()
round(avg_reps, 2)

# %%
# Average weight lifted in workouts
avg_weight = workout_data["weight_lbs"].mean()
round(avg_weight, 2)
